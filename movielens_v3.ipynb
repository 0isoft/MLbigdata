# %% [markdown]
# variational autoencoder architecture , movielens, best combination of hyperparameters determined at the end

# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
import torch
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Load MovieLens data
ratings_data = pd.read_csv('ratings.csv', usecols=['userId', 'movieId', 'rating'])
movies_data = pd.read_csv('movies.csv', usecols=['movieId', 'title', 'genres'])

# Merge the ratings and movies dataframes to include movie titles in the ratings dataframe
merged_data = pd.merge(ratings_data, movies_data, on='movieId')

# Count the number of ratings for each movie
movie_rating_counts = ratings_data['movieId'].value_counts()

# Get the top 3000 movies
top_5000_movie_ids = movie_rating_counts.head(5000).index

# Filter the ratings to keep only those from the top 3000 movies
filtered_ratings_data = ratings_data[ratings_data['movieId'].isin(top_5000_movie_ids)]

# Get the users who have rated these top 3000 movies
users_with_top_movie_ratings = filtered_ratings_data['userId'].unique()

# Filter the ratings to keep only those from these users
filtered_ratings_data = filtered_ratings_data[filtered_ratings_data['userId'].isin(users_with_top_movie_ratings)]

# Function to get reviews for a specific user and include movie titles
def get_user_reviews(user_id, data):
    user_reviews = data[data['userId'] == user_id]
    return user_reviews

# Select a specific user ID
specific_user_id = 1  # You can change this to any user ID you want

# Get the reviews for the specific user
user_reviews = get_user_reviews(specific_user_id, filtered_ratings_data)

# Check if there are any reviews for this user
if not user_reviews.empty:
    print(f"Reviews for user {specific_user_id}:")
    user_reviews = pd.merge(user_reviews, movies_data, on='movieId')
    print(user_reviews[['userId', 'movieId', 'rating', 'title']])
else:
    print(f"No reviews found for user {specific_user_id}.")

# Check if the specific user ID exists in the original ratings dataframe
print(f"Does user ID {specific_user_id} exist in the original DataFrame? {'Yes' if specific_user_id in ratings_data['userId'].values else 'No'}")
# Out:
# Reviews for user 1:
#     userId  movieId  rating                                              title
# 0        1      296     5.0                                Pulp Fiction (1994)
# 1        1      306     3.5   Three Colors: Red (Trois couleurs: Rouge) (1994)
# 2        1      307     5.0   Three Colors: Blue (Trois couleurs: Bleu) (1993)
# 3        1      665     5.0                                 Underground (1995)
# 4        1      899     3.5                         Singin' in the Rain (1952)
# 5        1     1088     4.0                               Dirty Dancing (1987)
# 6        1     1175     3.5                                Delicatessen (1991)
# 7        1     1217     3.5                                         Ran (1985)
# 8        1     1237     5.0    Seventh Seal, The (Sjunde inseglet, Det) (1957)
# 9        1     1250     4.0               Bridge on the River Kwai, The (1957)
# 10       1     1260     3.5                                           M (1931)
# 11       1     1653     4.0                                     Gattaca (1997)
# 12       1     2011     2.5                  Back to the Future Part II (1989)
# 13       1     2012     2.5                 Back to the Future Part III (1990)
# 14       1     2068     2.5   Fanny and Alexander (Fanny och Alexander) (1982)
# 15       1     2161     3.5                      NeverEnding Story, The (1984)
# 16       1     2351     4.5    Nights of Cabiria (Notti di Cabiria, Le) (1957)
# 17       1     2692     5.0                   Run Lola Run (Lola rennt) (1998)
# 18       1     2843     4.5  Black Cat, White Cat (Crna macka, beli macor) ...
# 19       1     3448     4.0                       Good Morning, Vietnam (1987)
# 20       1     3569     5.0                     Idiots, The (Idioterne) (1998)
# 21       1     3949     5.0                         Requiem for a Dream (2000)
# 22       1     4144     5.0      In the Mood For Love (Fa yeung nin wa) (2000)
# 23       1     4308     3.0                                Moulin Rouge (2001)
# 24       1     4422     3.0     Cries and Whispers (Viskningar och rop) (1972)
# 25       1     4703     4.0                                    Chocolat (1988)
# 26       1     4973     4.5  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 27       1     5147     4.0         Wild Strawberries (Smultronstället) (1957)
# 28       1     5269     0.5            Piano Teacher, The (La pianiste) (2001)
# 29       1     5878     4.0                Talk to Her (Hable con Ella) (2002)
# 30       1     5952     4.0      Lord of the Rings: The Two Towers, The (2002)
# 31       1     6016     5.0                City of God (Cidade de Deus) (2002)
# 32       1     6370     4.5  Spanish Apartment, The (L'auberge espagnole) (...
# 33       1     6377     4.0                                Finding Nemo (2003)
# 34       1     6539     3.5  Pirates of the Caribbean: The Curse of the Bla...
# 35       1     6711     5.0                         Lost in Translation (2003)
# 36       1     6954     3.5  Barbarian Invasions, The (Les invasions barbar...
# 37       1     7209     4.0  M. Hulot’s Holiday (Mr. Hulot's Holiday) (Vaca...
# 38       1     7234     4.5                                  Strada, La (1954)
# 39       1     7318     2.0                  Passion of the Christ, The (2004)
# 40       1     7323     3.5                            Good bye, Lenin! (2003)
# 41       1     7327     3.5                                     Persona (1966)
# 42       1     7361     5.0       Eternal Sunshine of the Spotless Mind (2004)
# 43       1     7820     2.5          Virgin Spring, The (Jungfrukällan) (1960)
# 44       1     8014     3.5  Spring, Summer, Fall, Winter... and Spring (Bo...
# 45       1     8154     5.0                              Dolce Vita, La (1960)
# 46       1     8360     4.0                                     Shrek 2 (2004)
# 47       1     8873     3.0  Motorcycle Diaries, The (Diarios de motociclet...
# 48       1     8973     4.0           Bad Education (La mala educación) (2004)
# 49       1    27193     3.0                                      Taxi 2 (2000)
# 50       1    27266     4.5                                        2046 (2004)
# 51       1    27721     3.0  Very Long Engagement, A (Un long dimanche de f...
# Does user ID 1 exist in the original DataFrame? Yes

# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
ratings_data = filtered_ratings_data

# Check unique user and movie IDs before factorization
unique_user_ids = ratings_data['userId'].nunique()
unique_movie_ids = ratings_data['movieId'].nunique()
print(f"Unique userIds before factorization: {unique_user_ids}")
print(f"Unique movieIds before factorization: {unique_movie_ids}")

# Ensure specific user ID exists in the original DataFrame
specific_user_id = 1  # Change to the desired user ID
print(f"Does user ID {specific_user_id} exist in the original DataFrame? {'Yes' if specific_user_id in ratings_data['userId'].values else 'No'}")

# Factorize user and movie IDs
user_id_mapping, user_unique_ids = pd.factorize(ratings_data['userId'])
movie_id_mapping, movie_unique_ids = pd.factorize(ratings_data['movieId'])

# Create DataFrame to map factorized IDs back to original IDs
user_id_map_df = pd.DataFrame({'original_user_id': user_unique_ids, 'factorized_user_id': range(len(user_unique_ids))})
movie_id_map_df = pd.DataFrame({'original_movie_id': movie_unique_ids, 'factorized_movie_id': range(len(movie_unique_ids))})

# Debugging: Check if the specific user ID is in the unique user IDs
print(f"Is specific user ID {specific_user_id} in unique user IDs? {'Yes' if specific_user_id in user_unique_ids else 'No'}")

# Replace the original IDs with the factorized IDs
ratings_data['userId'] = user_id_mapping
ratings_data['movieId'] = movie_id_mapping

# Check unique user and movie IDs after factorization
unique_user_ids_after = ratings_data['userId'].nunique()
unique_movie_ids_after = ratings_data['movieId'].nunique()
print(f"Unique userIds after factorization: {unique_user_ids_after}")
print(f"Unique movieIds after factorization: {unique_movie_ids_after}")

# Get max user and movie IDs
max_user_id = user_id_mapping.max() + 1
max_movie_id = movie_id_mapping.max() + 1
print(f"Max movie id: {max_movie_id}, Max user id: {max_user_id}")

# Normalize ratings
min_rating = ratings_data['rating'].min()
max_rating = ratings_data['rating'].max()
ratings_data['rating'] = (ratings_data['rating'] - min_rating) / (max_rating - min_rating)

# Create the user-item matrix and the mask matrix
data = ratings_data['rating'].values
rows = ratings_data['userId'].values
cols = ratings_data['movieId'].values

user_item_matrix = csr_matrix((data, (rows, cols)), shape=(max_user_id, max_movie_id))
genuine_ratings_mask = csr_matrix((np.ones_like(data), (rows, cols)), shape=(max_user_id, max_movie_id))

print(f"User-item matrix shape: {user_item_matrix.shape}")
print(f"User-item matrix non-zero count: {user_item_matrix.nnz}")
print(f"Mask matrix shape: {genuine_ratings_mask.shape}")
print(f"Mask matrix non-zero count: {genuine_ratings_mask.nnz}")

# Helper functions to map factorized IDs back to original IDs
def factorized_to_original_user_id(factorized_id):
    return user_id_map_df.loc[user_id_map_df['factorized_user_id'] == factorized_id, 'original_user_id'].values[0]

def factorized_to_original_movie_id(factorized_id):
    return movie_id_map_df.loc[movie_id_map_df['factorized_movie_id'] == factorized_id, 'original_movie_id'].values[0]

def original_to_factorized_user_id(original_id):
    if original_id in user_id_map_df['original_user_id'].values:
        return user_id_map_df.loc[user_id_map_df['original_user_id'] == original_id, 'factorized_user_id'].values[0]
    else:
        print(f"Original user ID {original_id} not found.")
        return None

def original_to_factorized_movie_id(original_id):
    if original_id in movie_id_map_df['original_movie_id'].values:
        return movie_id_map_df.loc[movie_id_map_df['original_movie_id'] == original_id, 'factorized_movie_id'].values[0]
    else:
        print(f"Original movie ID {original_id} not found.")
        return None

# Map to factorized ID
factorized_user_id = original_to_factorized_user_id(specific_user_id)
# Debugging: Check if the specific user ID is in the unique user IDs
print(f"Is specific user ID {specific_user_id} in unique user IDs? {'Yes' if specific_user_id in user_unique_ids else 'No'}")

if factorized_user_id is not None:
    # Extract user's reviews from the user-item matrix
    user_ratings = user_item_matrix.getrow(factorized_user_id).toarray().flatten()
    rated_movie_indices = np.where(user_ratings > 0)[0]
    ratings = user_ratings[rated_movie_indices]

    # Map factorized movie IDs back to original IDs
    original_movie_ids = [factorized_to_original_movie_id(movie_id) for movie_id in rated_movie_indices]

    # Get movie titles using the original movie IDs
    movie_titles = movies_data[movies_data['movieId'].isin(original_movie_ids)]

    # Print the results
    print(f"Reviews for user {specific_user_id} (Factorized ID: {factorized_user_id}):")
    for original_movie_id, rating in zip(original_movie_ids, ratings):
        movie_title = movie_titles[movie_titles['movieId'] == original_movie_id]['title'].values[0]
        print(f"Movie: {movie_title}, Original Movie ID: {original_movie_id}, Rating: {rating * (max_rating - min_rating) + min_rating}")
else:
    print(f"Factorized user ID for {specific_user_id} not found.")
# Out:
# Unique userIds before factorization: 162539
# Unique movieIds before factorization: 5000
# Does user ID 1 exist in the original DataFrame? Yes
# Is specific user ID 1 in unique user IDs? Yes
# Unique userIds after factorization: 162539
# Unique movieIds after factorization: 5000
# Max movie id: 5000, Max user id: 162539
# User-item matrix shape: (162539, 5000)
# User-item matrix non-zero count: 23062613
# Mask matrix shape: (162539, 5000)
# Mask matrix non-zero count: 23062613
# Is specific user ID 1 in unique user IDs? Yes
# Reviews for user 1 (Factorized ID: 0):
# Movie: Pulp Fiction (1994), Original Movie ID: 296, Rating: 5.0
# Movie: Three Colors: Red (Trois couleurs: Rouge) (1994), Original Movie ID: 306, Rating: 3.5
# Movie: Three Colors: Blue (Trois couleurs: Bleu) (1993), Original Movie ID: 307, Rating: 5.0
# Movie: Underground (1995), Original Movie ID: 665, Rating: 5.0
# Movie: Singin' in the Rain (1952), Original Movie ID: 899, Rating: 3.5
# Movie: Dirty Dancing (1987), Original Movie ID: 1088, Rating: 4.0
# Movie: Delicatessen (1991), Original Movie ID: 1175, Rating: 3.5
# Movie: Ran (1985), Original Movie ID: 1217, Rating: 3.5
# Movie: Seventh Seal, The (Sjunde inseglet, Det) (1957), Original Movie ID: 1237, Rating: 5.0
# Movie: Bridge on the River Kwai, The (1957), Original Movie ID: 1250, Rating: 4.0
# Movie: M (1931), Original Movie ID: 1260, Rating: 3.5
# Movie: Gattaca (1997), Original Movie ID: 1653, Rating: 4.0
# Movie: Back to the Future Part II (1989), Original Movie ID: 2011, Rating: 2.5
# Movie: Back to the Future Part III (1990), Original Movie ID: 2012, Rating: 2.5
# Movie: Fanny and Alexander (Fanny och Alexander) (1982), Original Movie ID: 2068, Rating: 2.5
# Movie: NeverEnding Story, The (1984), Original Movie ID: 2161, Rating: 3.5
# Movie: Nights of Cabiria (Notti di Cabiria, Le) (1957), Original Movie ID: 2351, Rating: 4.5
# Movie: Run Lola Run (Lola rennt) (1998), Original Movie ID: 2692, Rating: 5.0
# Movie: Black Cat, White Cat (Crna macka, beli macor) (1998), Original Movie ID: 2843, Rating: 4.5
# Movie: Good Morning, Vietnam (1987), Original Movie ID: 3448, Rating: 4.0
# Movie: Idiots, The (Idioterne) (1998), Original Movie ID: 3569, Rating: 5.0
# Movie: Requiem for a Dream (2000), Original Movie ID: 3949, Rating: 5.0
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Original Movie ID: 4144, Rating: 5.0
# Movie: Moulin Rouge (2001), Original Movie ID: 4308, Rating: 3.0
# Movie: Cries and Whispers (Viskningar och rop) (1972), Original Movie ID: 4422, Rating: 3.0
# Movie: Chocolat (1988), Original Movie ID: 4703, Rating: 4.0
# Movie: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Original Movie ID: 4973, Rating: 4.5
# Movie: Wild Strawberries (Smultronstället) (1957), Original Movie ID: 5147, Rating: 4.0
# Movie: Talk to Her (Hable con Ella) (2002), Original Movie ID: 5878, Rating: 4.0
# Movie: Lord of the Rings: The Two Towers, The (2002), Original Movie ID: 5952, Rating: 4.0
# Movie: City of God (Cidade de Deus) (2002), Original Movie ID: 6016, Rating: 5.0
# Movie: Spanish Apartment, The (L'auberge espagnole) (2002), Original Movie ID: 6370, Rating: 4.5
# Movie: Finding Nemo (2003), Original Movie ID: 6377, Rating: 4.0
# Movie: Pirates of the Caribbean: The Curse of the Black Pearl (2003), Original Movie ID: 6539, Rating: 3.5
# Movie: Lost in Translation (2003), Original Movie ID: 6711, Rating: 5.0
# Movie: Barbarian Invasions, The (Les invasions barbares) (2003), Original Movie ID: 6954, Rating: 3.5
# Movie: M. Hulot’s Holiday (Mr. Hulot's Holiday) (Vacances de Monsieur Hulot, Les) (1953), Original Movie ID: 7209, Rating: 4.0
# Movie: Strada, La (1954), Original Movie ID: 7234, Rating: 4.5
# Movie: Passion of the Christ, The (2004), Original Movie ID: 7318, Rating: 2.0
# Movie: Good bye, Lenin! (2003), Original Movie ID: 7323, Rating: 3.5
# Movie: Persona (1966), Original Movie ID: 7327, Rating: 3.5
# Movie: Eternal Sunshine of the Spotless Mind (2004), Original Movie ID: 7361, Rating: 5.0
# Movie: Virgin Spring, The (Jungfrukällan) (1960), Original Movie ID: 7820, Rating: 2.5
# Movie: Spring, Summer, Fall, Winter... and Spring (Bom yeoreum gaeul gyeoul geurigo bom) (2003), Original Movie ID: 8014, Rating: 3.5
# Movie: Dolce Vita, La (1960), Original Movie ID: 8154, Rating: 5.0
# Movie: Shrek 2 (2004), Original Movie ID: 8360, Rating: 4.0
# Movie: Motorcycle Diaries, The (Diarios de motocicleta) (2004), Original Movie ID: 8873, Rating: 3.0
# Movie: Bad Education (La mala educación) (2004), Original Movie ID: 8973, Rating: 4.0
# Movie: Taxi 2 (2000), Original Movie ID: 27193, Rating: 3.0
# Movie: 2046 (2004), Original Movie ID: 27266, Rating: 4.5
# Movie: Very Long Engagement, A (Un long dimanche de fiançailles) (2004), Original Movie ID: 27721, Rating: 3.0

# %%
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import torch

# Split the data
train_indices, test_indices = train_test_split(np.arange(user_item_matrix.shape[0]), test_size=0.2, random_state=42)
train_indices, val_indices = train_test_split(train_indices, test_size=0.25, random_state=42)

print(f"Is factorized user ID {factorized_user_id} in training indices? {'Yes' if factorized_user_id in train_indices else 'No'}")
print(f"Is factorized user ID {factorized_user_id} in validation indices? {'Yes' if factorized_user_id in val_indices else 'No'}")
print(f"Is factorized user ID {factorized_user_id} in test indices? {'Yes' if factorized_user_id in test_indices else 'No'}")

# Create datasets
class CSRDataset(Dataset):
    def __init__(self, user_item_matrix, mask_matrix, indices):
        self.user_item_matrix = user_item_matrix
        self.mask_matrix = mask_matrix
        self.indices = indices
        print(f"Dataset initialized with {len(self.indices)} users.")

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
        user_idx = self.indices[idx]
        dense_row = self.user_item_matrix[user_idx].toarray().squeeze(0)
        mask_row = self.mask_matrix[user_idx].toarray().squeeze(0)
        dense_tensor = torch.from_numpy(dense_row).float()
        mask_tensor = torch.from_numpy(mask_row).float()
        return dense_tensor, mask_tensor

train_dataset = CSRDataset(user_item_matrix, genuine_ratings_mask, train_indices)
val_dataset = CSRDataset(user_item_matrix, genuine_ratings_mask, val_indices)
test_dataset = CSRDataset(user_item_matrix, genuine_ratings_mask, test_indices)

# Function to extract ratings and corresponding mask values for a user
def get_user_data(dataset, user_id):
    for idx in range(len(dataset)):
        user_idx = dataset.indices[idx]
        if user_idx == user_id:
            dense_tensor, mask_tensor = dataset[idx]
            user_ratings = dense_tensor.numpy()
            user_mask = mask_tensor.numpy()
            return user_ratings, user_mask
    return None, None

# Get the data for the specific user
user_ratings, user_mask = get_user_data(val_dataset, factorized_user_id)

if user_ratings is not None and user_mask is not None:
    # Filter out the indices where the mask is non-zero
    mask_non_zero_indices = np.nonzero(user_mask)[0]
    mask_non_zero_ratings = user_ratings[mask_non_zero_indices]
    mask_non_zero_mask = user_mask[mask_non_zero_indices]

    # Print results
    print(f"Indices with non-zero mask values: {mask_non_zero_indices}")
    print(f"Ratings at these indices: {mask_non_zero_ratings}")
    print(f"Mask values at these indices: {mask_non_zero_mask}")
else:
    print(f"User {factorized_user_id} not found in the validation dataset.")
# Out:
# Is factorized user ID 0 in training indices? No
# Is factorized user ID 0 in validation indices? No
# Is factorized user ID 0 in test indices? Yes
# Dataset initialized with 97523 users.
# Dataset initialized with 32508 users.
# Dataset initialized with 32508 users.
# User 0 not found in the validation dataset.

# %%
import torch
from torch.utils.data import DataLoader

# Function to find and print a specific user's data from the CSRDataset
def check_integrity_of_dataset(dataset, factorized_user_id, dataset_name):
    found = False
    for idx in range(len(dataset)):
        user_idx = dataset.indices[idx]
        if user_idx == factorized_user_id:
            dense_tensor, mask_tensor = dataset[idx]
            user_ratings = dense_tensor.numpy()
            user_mask = mask_tensor.numpy()

            rated_movie_indices = np.where(user_mask > 0)[0]
            ratings = user_ratings[rated_movie_indices]

            if len(ratings) > 0:
                found = True
                # Map factorized movie IDs back to original IDs
                original_movie_ids = [factorized_to_original_movie_id(movie_id) for movie_id in rated_movie_indices]

                # Get movie titles using the original movie IDs
                movie_titles = movies_data[movies_data['movieId'].isin(original_movie_ids)]

                # Print the results
                print(f"{dataset_name} - Reviews for user {specific_user_id} (Factorized ID: {factorized_user_id}):")
                for original_movie_id, rating in zip(original_movie_ids, ratings):
                    movie_title = movie_titles[movie_titles['movieId'] == original_movie_id]['title'].values[0]
                    print(f"Movie: {movie_title}, Original Movie ID: {original_movie_id}, Rating: {rating * (max_rating - min_rating) + min_rating}")
                break

    if not found:
        print(f"User {factorized_user_id} not found in {dataset_name} dataset.")

# Map the specific original user ID to the factorized user ID
specific_user_id = 1  # Change this to the desired user ID
factorized_user_id = original_to_factorized_user_id(specific_user_id)

if factorized_user_id is not None:
    # Check the integrity of the datasets
    check_integrity_of_dataset(train_dataset, factorized_user_id, "Train")
    check_integrity_of_dataset(val_dataset, factorized_user_id, "Validation")
    check_integrity_of_dataset(test_dataset, factorized_user_id, "Test")
else:
    print(f"Factorized user ID for {specific_user_id} not found.")
# Out:
# User 0 not found in Train dataset.
# User 0 not found in Validation dataset.
# Test - Reviews for user 1 (Factorized ID: 0):
# Movie: Pulp Fiction (1994), Original Movie ID: 296, Rating: 5.0
# Movie: Three Colors: Red (Trois couleurs: Rouge) (1994), Original Movie ID: 306, Rating: 3.500000089406967
# Movie: Three Colors: Blue (Trois couleurs: Bleu) (1993), Original Movie ID: 307, Rating: 5.0
# Movie: Underground (1995), Original Movie ID: 665, Rating: 5.0
# Movie: Singin' in the Rain (1952), Original Movie ID: 899, Rating: 3.500000089406967
# Movie: Dirty Dancing (1987), Original Movie ID: 1088, Rating: 4.000000059604645
# Movie: Delicatessen (1991), Original Movie ID: 1175, Rating: 3.500000089406967
# Movie: Ran (1985), Original Movie ID: 1217, Rating: 3.500000089406967
# Movie: Seventh Seal, The (Sjunde inseglet, Det) (1957), Original Movie ID: 1237, Rating: 5.0
# Movie: Bridge on the River Kwai, The (1957), Original Movie ID: 1250, Rating: 4.000000059604645
# Movie: M (1931), Original Movie ID: 1260, Rating: 3.500000089406967
# Movie: Gattaca (1997), Original Movie ID: 1653, Rating: 4.000000059604645
# Movie: Back to the Future Part II (1989), Original Movie ID: 2011, Rating: 2.500000014901161
# Movie: Back to the Future Part III (1990), Original Movie ID: 2012, Rating: 2.500000014901161
# Movie: Fanny and Alexander (Fanny och Alexander) (1982), Original Movie ID: 2068, Rating: 2.500000014901161
# Movie: NeverEnding Story, The (1984), Original Movie ID: 2161, Rating: 3.500000089406967
# Movie: Nights of Cabiria (Notti di Cabiria, Le) (1957), Original Movie ID: 2351, Rating: 4.500000029802322
# Movie: Run Lola Run (Lola rennt) (1998), Original Movie ID: 2692, Rating: 5.0
# Movie: Black Cat, White Cat (Crna macka, beli macor) (1998), Original Movie ID: 2843, Rating: 4.500000029802322
# Movie: Good Morning, Vietnam (1987), Original Movie ID: 3448, Rating: 4.000000059604645
# Movie: Idiots, The (Idioterne) (1998), Original Movie ID: 3569, Rating: 5.0
# Movie: Requiem for a Dream (2000), Original Movie ID: 3949, Rating: 5.0
# Movie: In the Mood For Love (Fa yeung nin wa) (2000), Original Movie ID: 4144, Rating: 5.0
# Movie: Moulin Rouge (2001), Original Movie ID: 4308, Rating: 3.0000001192092896
# Movie: Cries and Whispers (Viskningar och rop) (1972), Original Movie ID: 4422, Rating: 3.0000001192092896
# Movie: Chocolat (1988), Original Movie ID: 4703, Rating: 4.000000059604645
# Movie: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Original Movie ID: 4973, Rating: 4.500000029802322
# Movie: Wild Strawberries (Smultronstället) (1957), Original Movie ID: 5147, Rating: 4.000000059604645
# Movie: Piano Teacher, The (La pianiste) (2001), Original Movie ID: 5269, Rating: 0.5
# Movie: Talk to Her (Hable con Ella) (2002), Original Movie ID: 5878, Rating: 4.000000059604645
# Movie: Lord of the Rings: The Two Towers, The (2002), Original Movie ID: 5952, Rating: 4.000000059604645
# Movie: City of God (Cidade de Deus) (2002), Original Movie ID: 6016, Rating: 5.0
# Movie: Spanish Apartment, The (L'auberge espagnole) (2002), Original Movie ID: 6370, Rating: 4.500000029802322
# Movie: Finding Nemo (2003), Original Movie ID: 6377, Rating: 4.000000059604645
# Movie: Pirates of the Caribbean: The Curse of the Black Pearl (2003), Original Movie ID: 6539, Rating: 3.500000089406967
# Movie: Lost in Translation (2003), Original Movie ID: 6711, Rating: 5.0
# Movie: Barbarian Invasions, The (Les invasions barbares) (2003), Original Movie ID: 6954, Rating: 3.500000089406967
# Movie: M. Hulot’s Holiday (Mr. Hulot's Holiday) (Vacances de Monsieur Hulot, Les) (1953), Original Movie ID: 7209, Rating: 4.000000059604645
# Movie: Strada, La (1954), Original Movie ID: 7234, Rating: 4.500000029802322
# Movie: Passion of the Christ, The (2004), Original Movie ID: 7318, Rating: 2.0000000447034836
# Movie: Good bye, Lenin! (2003), Original Movie ID: 7323, Rating: 3.500000089406967
# Movie: Persona (1966), Original Movie ID: 7327, Rating: 3.500000089406967
# Movie: Eternal Sunshine of the Spotless Mind (2004), Original Movie ID: 7361, Rating: 5.0
# Movie: Virgin Spring, The (Jungfrukällan) (1960), Original Movie ID: 7820, Rating: 2.500000014901161
# Movie: Spring, Summer, Fall, Winter... and Spring (Bom yeoreum gaeul gyeoul geurigo bom) (2003), Original Movie ID: 8014, Rating: 3.500000089406967
# Movie: Dolce Vita, La (1960), Original Movie ID: 8154, Rating: 5.0
# Movie: Shrek 2 (2004), Original Movie ID: 8360, Rating: 4.000000059604645
# Movie: Motorcycle Diaries, The (Diarios de motocicleta) (2004), Original Movie ID: 8873, Rating: 3.0000001192092896
# Movie: Bad Education (La mala educación) (2004), Original Movie ID: 8973, Rating: 4.000000059604645
# Movie: Taxi 2 (2000), Original Movie ID: 27193, Rating: 3.0000001192092896
# Movie: 2046 (2004), Original Movie ID: 27266, Rating: 4.500000029802322
# Movie: Very Long Engagement, A (Un long dimanche de fiançailles) (2004), Original Movie ID: 27721, Rating: 3.0000001192092896

# %%
import torch
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# Dataloaders
batch_size = 128
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# Print loader info
def print_loader_info(loader, name):
    for i, (data, mask) in enumerate(loader):
        if i == 0:
            print(f"{name} - First batch info:")
            print(f"Batch shape: {data.shape}")
            print(f"Batch type: {data.dtype}")
            print(f"Mask shape: {mask.shape}")
            print(f"Mask type: {mask.dtype}")
            print(f"Number of samples in batch: {data.size(0)}")
            break

print_loader_info(train_loader, "MovieLens Train Loader")
print_loader_info(val_loader, "MovieLens Validation Loader")
print_loader_info(test_loader, "MovieLens Test Loader")

# Plot the distribution of the data
plt.figure(figsize=(8, 6))
ratings_data['rating'].hist(bins=30)
plt.title('MovieLens Rating Distribution')
plt.xlabel('Normalized Ratings')
plt.ylabel('Frequency')
plt.show()
# Out:
# MovieLens Train Loader - First batch info:
# Batch shape: torch.Size([128, 5000])
# Batch type: torch.float32
# Mask shape: torch.Size([128, 5000])
# Mask type: torch.float32
# Number of samples in batch: 128
# MovieLens Validation Loader - First batch info:
# Batch shape: torch.Size([128, 5000])
# Batch type: torch.float32
# Mask shape: torch.Size([128, 5000])
# Mask type: torch.float32
# Number of samples in batch: 128
# MovieLens Test Loader - First batch info:
# Batch shape: torch.Size([128, 5000])
# Batch type: torch.float32
# Mask shape: torch.Size([128, 5000])
# Mask type: torch.float32
# Number of samples in batch: 128

# %%
# Split the data
user_indices = np.arange(user_item_matrix.shape[0])

# Initial split to separate out the test set
train_val_indices, test_indices = train_test_split(user_indices, test_size=0.2, random_state=42)

# Further split the training and validation sets
train_indices, val_indices = train_test_split(train_val_indices, test_size=0.25, random_state=42)

# Verify no overlap between sets
assert len(set(train_indices) & set(val_indices)) == 0, "Overlap between training and validation sets"
assert len(set(train_indices) & set(test_indices)) == 0, "Overlap between training and test sets"
assert len(set(val_indices) & set(test_indices)) == 0, "Overlap between validation and test sets"

print(f"Training set size: {len(train_indices)}")
print(f"Validation set size: {len(val_indices)}")
print(f"Test set size: {len(test_indices)}")
# Out:
# Training set size: 97523
# Validation set size: 32508
# Test set size: 32508

# %%
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
import numpy as np
import matplotlib.pyplot as plt

class Encoder(nn.Module):
    def __init__(self, input_dim, hidden_dims, latent_dim):
        super(Encoder, self).__init__()
        self.hidden_layers = nn.ModuleList()
        previous_dim = input_dim
        
        for hidden_dim in hidden_dims:
            self.hidden_layers.append(nn.Linear(previous_dim, hidden_dim))
            self.hidden_layers.append(nn.ReLU())
            previous_dim = hidden_dim
        
        self.mu_layer = nn.Linear(previous_dim, latent_dim)
        self.log_var_layer = nn.Linear(previous_dim, latent_dim)
    
    def forward(self, x):
        for layer in self.hidden_layers:
            x = layer(x)
        mu = self.mu_layer(x)
        log_var = self.log_var_layer(x)
        return mu, log_var

class Decoder(nn.Module):
    def __init__(self, output_dim, hidden_dims, latent_dim):
        super(Decoder, self).__init__()
        self.hidden_layers = nn.ModuleList()
        previous_dim = latent_dim
        
        for hidden_dim in reversed(hidden_dims):
            self.hidden_layers.append(nn.Linear(previous_dim, hidden_dim))
            self.hidden_layers.append(nn.ReLU())
            previous_dim = hidden_dim
        
        self.output_layer = nn.Linear(previous_dim, output_dim)
    
    def forward(self, z):
        for layer in self.hidden_layers:
            z = layer(z)
        return self.output_layer(z)

class VAE(nn.Module):
    def __init__(self, input_dim, hidden_dims, latent_dim):
        super(VAE, self).__init__()
        self.encoder = Encoder(input_dim, hidden_dims, latent_dim)
        self.decoder = Decoder(input_dim, hidden_dims, latent_dim)
    
    def reparameterize(self, mu, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return mu + eps * std
    
    def forward(self, x):
        mu, log_var = self.encoder(x)
        z = self.reparameterize(mu, log_var)
        reconstructed_x = self.decoder(z)
        return reconstructed_x, mu, log_var

# %%
def vae_loss_function(reconstructed_x, x, mask, mu, log_var):
    # Apply mask to both reconstructed and original data
    masked_reconstructed_x = reconstructed_x * mask
    masked_x = x * mask
    
    # Masked reconstruction loss
    recon_loss = ((masked_reconstructed_x - masked_x) ** 2).sum() / mask.sum()
    
    # KL Divergence
    kl_divergence = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
    
    return recon_loss + kl_divergence

# %%
import torch
import matplotlib.pyplot as plt

# Function to evaluate the model on a given data loader
def evaluate_model(model, data_loader, criterion, device):
    model.eval()
    total_loss = 0
    with torch.no_grad():
        for data, mask in data_loader:
            data = data.to(device)
            mask = mask.to(device)
            recon_data, mu, logvar = model(data)
            loss = criterion(recon_data, data, mask, mu, logvar)
            total_loss += loss.item()
    return total_loss / len(data_loader)

# Function to train the model
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs, device):
    model.train()
    train_losses = []
    val_losses = []
    best_val_loss = float('inf')
    patience = 5
    patience_counter = 0

    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0
        for batch_idx, (data, mask) in enumerate(train_loader):
            data = data.to(device)
            mask = mask.to(device)

            optimizer.zero_grad()
            recon_data, mu, logvar = model(data)
            loss = criterion(recon_data, data, mask, mu, logvar)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

            if (batch_idx + 1) % 100 == 0:
                print(f"Epoch [{epoch+1}/{num_epochs}], Batch [{batch_idx+1}/{len(train_loader)}], Loss: {loss.item():.4f}")

        scheduler.step()
        train_losses.append(epoch_loss / len(train_loader))

        val_loss = evaluate_model(model, val_loader, criterion, device)
        val_losses.append(val_loss)

        print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_losses[-1]:.4f}, Validation Loss: {val_losses[-1]:.4f}")

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"Early stopping at epoch {epoch+1}")
                break

    return train_losses, val_losses

# %%
# Training settings
input_dim = user_item_matrix.shape[1]
hidden_dims = [512, 256]
latent_dim = 128
learning_rate = 0.001
num_epochs = 15
batch_size = 128
device = torch.device('cpu')
# Initialize the model, criterion, optimizer, and scheduler
model = VAE(input_dim, hidden_dims, latent_dim).to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-5)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
criterion = vae_loss_function

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# Train the model
train_losses, val_losses = train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs, device)

# Plot the training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Epoch [1/15], Batch [100/762], Loss: 0.0875
# Epoch [1/15], Batch [200/762], Loss: 0.0578
# Epoch [1/15], Batch [300/762], Loss: 0.0589
# Epoch [1/15], Batch [400/762], Loss: 0.0597
# Epoch [1/15], Batch [500/762], Loss: 0.0555
# Epoch [1/15], Batch [600/762], Loss: 0.0478
# Epoch [1/15], Batch [700/762], Loss: 0.0610
# Epoch [1/15], Train Loss: 0.1675, Validation Loss: 0.0497
# Epoch [2/15], Batch [100/762], Loss: 0.0500
# Epoch [2/15], Batch [200/762], Loss: 0.0570
# Epoch [2/15], Batch [300/762], Loss: 0.0473
# Epoch [2/15], Batch [400/762], Loss: 0.0520
# Epoch [2/15], Batch [500/762], Loss: 0.0549
# Epoch [2/15], Batch [600/762], Loss: 0.0448
# Epoch [2/15], Batch [700/762], Loss: 0.0527
# Epoch [2/15], Train Loss: 0.0490, Validation Loss: 0.0482
# Epoch [3/15], Batch [100/762], Loss: 0.0464
# Epoch [3/15], Batch [200/762], Loss: 0.0468
# Epoch [3/15], Batch [300/762], Loss: 0.0464
# Epoch [3/15], Batch [400/762], Loss: 0.0439
# Epoch [3/15], Batch [500/762], Loss: 0.0515
# Epoch [3/15], Batch [600/762], Loss: 0.0565
# Epoch [3/15], Batch [700/762], Loss: 0.0442
# Epoch [3/15], Train Loss: 0.0475, Validation Loss: 0.0473
# Epoch [4/15], Batch [100/762], Loss: 0.0411
# Epoch [4/15], Batch [200/762], Loss: 0.0472
# Epoch [4/15], Batch [300/762], Loss: 0.0487
# Epoch [4/15], Batch [400/762], Loss: 0.0469
# Epoch [4/15], Batch [500/762], Loss: 0.0458
# Epoch [4/15], Batch [600/762], Loss: 0.0722
# Epoch [4/15], Batch [700/762], Loss: 0.0487
# Epoch [4/15], Train Loss: 0.0469, Validation Loss: 0.0464
# Epoch [5/15], Batch [100/762], Loss: 0.0470
# Epoch [5/15], Batch [200/762], Loss: 0.0471
# Epoch [5/15], Batch [300/762], Loss: 0.0424
# Epoch [5/15], Batch [400/762], Loss: 0.0459
# Epoch [5/15], Batch [500/762], Loss: 0.0452
# Epoch [5/15], Batch [600/762], Loss: 0.0379
# Epoch [5/15], Batch [700/762], Loss: 0.0481
# Epoch [5/15], Train Loss: 0.0467, Validation Loss: 0.0464
# Epoch [6/15], Batch [100/762], Loss: 0.0446
# Epoch [6/15], Batch [200/762], Loss: 0.0462
# Epoch [6/15], Batch [300/762], Loss: 0.0436
# Epoch [6/15], Batch [400/762], Loss: 0.0454
# Epoch [6/15], Batch [500/762], Loss: 0.0501
# Epoch [6/15], Batch [600/762], Loss: 0.0437
# Epoch [6/15], Batch [700/762], Loss: 0.0487
# Epoch [6/15], Train Loss: 0.0462, Validation Loss: 0.0461
# Epoch [7/15], Batch [100/762], Loss: 0.0448
# Epoch [7/15], Batch [200/762], Loss: 0.0539
# Epoch [7/15], Batch [300/762], Loss: 0.0384
# Epoch [7/15], Batch [400/762], Loss: 0.0538
# Epoch [7/15], Batch [500/762], Loss: 0.0451
# Epoch [7/15], Batch [600/762], Loss: 0.0428
# Epoch [7/15], Batch [700/762], Loss: 0.0480
# Epoch [7/15], Train Loss: 0.0463, Validation Loss: 0.0460
# Epoch [8/15], Batch [100/762], Loss: 0.0471
# Epoch [8/15], Batch [200/762], Loss: 0.0453
# Epoch [8/15], Batch [300/762], Loss: 0.0408
# Epoch [8/15], Batch [400/762], Loss: 0.0471
# Epoch [8/15], Batch [500/762], Loss: 0.0442
# Epoch [8/15], Batch [600/762], Loss: 0.0422
# Epoch [8/15], Batch [700/762], Loss: 0.0411
# Epoch [8/15], Train Loss: 0.0461, Validation Loss: 0.0460
# Epoch [9/15], Batch [100/762], Loss: 0.0456
# Epoch [9/15], Batch [200/762], Loss: 0.0442
# Epoch [9/15], Batch [300/762], Loss: 0.0449
# Epoch [9/15], Batch [400/762], Loss: 0.0411
# Epoch [9/15], Batch [500/762], Loss: 0.0481
# Epoch [9/15], Batch [600/762], Loss: 0.0478
# Epoch [9/15], Batch [700/762], Loss: 0.0476
# Epoch [9/15], Train Loss: 0.0461, Validation Loss: 0.0461
# Epoch [10/15], Batch [100/762], Loss: 0.0521
# Epoch [10/15], Batch [200/762], Loss: 0.0483
# Epoch [10/15], Batch [300/762], Loss: 0.0391
# Epoch [10/15], Batch [400/762], Loss: 0.0390
# Epoch [10/15], Batch [500/762], Loss: 0.0418
# Epoch [10/15], Batch [600/762], Loss: 0.0461
# Epoch [10/15], Batch [700/762], Loss: 0.0510
# Epoch [10/15], Train Loss: 0.0462, Validation Loss: 0.0457
# Epoch [11/15], Batch [100/762], Loss: 0.0433
# Epoch [11/15], Batch [200/762], Loss: 0.0366
# Epoch [11/15], Batch [300/762], Loss: 0.0457
# Epoch [11/15], Batch [400/762], Loss: 0.0428
# Epoch [11/15], Batch [500/762], Loss: 0.0461
# Epoch [11/15], Batch [600/762], Loss: 0.0416
# Epoch [11/15], Batch [700/762], Loss: 0.0411
# Epoch [11/15], Train Loss: 0.0453, Validation Loss: 0.0450
# Epoch [12/15], Batch [100/762], Loss: 0.0457
# Epoch [12/15], Batch [200/762], Loss: 0.0424
# Epoch [12/15], Batch [300/762], Loss: 0.0398
# Epoch [12/15], Batch [400/762], Loss: 0.0558
# Epoch [12/15], Batch [500/762], Loss: 0.0432
# Epoch [12/15], Batch [600/762], Loss: 0.0382
# Epoch [12/15], Batch [700/762], Loss: 0.0431
# Epoch [12/15], Train Loss: 0.0451, Validation Loss: 0.0450
# Epoch [13/15], Batch [100/762], Loss: 0.0447
# Epoch [13/15], Batch [200/762], Loss: 0.0467
# Epoch [13/15], Batch [300/762], Loss: 0.0509
# Epoch [13/15], Batch [400/762], Loss: 0.0479
# Epoch [13/15], Batch [500/762], Loss: 0.0402
# Epoch [13/15], Batch [600/762], Loss: 0.0401
# Epoch [13/15], Batch [700/762], Loss: 0.0407
# Epoch [13/15], Train Loss: 0.0451, Validation Loss: 0.0451
# Epoch [14/15], Batch [100/762], Loss: 0.0487
# Epoch [14/15], Batch [200/762], Loss: 0.0505
# Epoch [14/15], Batch [300/762], Loss: 0.0541
# Epoch [14/15], Batch [400/762], Loss: 0.0454
# Epoch [14/15], Batch [500/762], Loss: 0.0501
# Epoch [14/15], Batch [600/762], Loss: 0.0444
# Epoch [14/15], Batch [700/762], Loss: 0.0464
# Epoch [14/15], Train Loss: 0.0451, Validation Loss: 0.0451
# Epoch [15/15], Batch [100/762], Loss: 0.0447
# Epoch [15/15], Batch [200/762], Loss: 0.0471
# Epoch [15/15], Batch [300/762], Loss: 0.0417
# Epoch [15/15], Batch [400/762], Loss: 0.0478
# Epoch [15/15], Batch [500/762], Loss: 0.0582
# Epoch [15/15], Batch [600/762], Loss: 0.0457
# Epoch [15/15], Batch [700/762], Loss: 0.0449
# Epoch [15/15], Train Loss: 0.0451, Validation Loss: 0.0450

# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Function to compare predicted and actual ratings for a specific user
def compare_user_ratings_normalized(user_id, model, device):
    model.eval()  # Set the model to evaluation mode
    with torch.no_grad():  # Disable gradient computation
        user_idx = original_to_factorized_user_id(user_id)
        if user_idx is not None:
            user_data = user_item_matrix.getrow(user_idx).toarray().flatten()
            user_mask = genuine_ratings_mask.getrow(user_idx).toarray().flatten()
            user_tensor = torch.from_numpy(user_data).float().to(device).unsqueeze(0)
            user_mask_tensor = torch.from_numpy(user_mask).float().to(device).unsqueeze(0)

            reconstructed_data, mu, logvar = model(user_tensor)  # Forward pass through the VAE
            user_output = reconstructed_data.cpu().numpy().flatten()
            user_ratings = user_tensor.cpu().numpy().flatten()

            # Filter only the movies that the user has rated
            reviewed_indices = np.where(user_mask > 0)[0]
            original_ratings = user_ratings[reviewed_indices]
            predicted_ratings = user_output[reviewed_indices]

            df = pd.DataFrame({
                'MovieID': reviewed_indices,
                'OriginalRating': original_ratings,
                'PredictedRating': predicted_ratings
            })

            # Map factorized movie IDs back to original IDs
            df['MovieID'] = df['MovieID'].apply(lambda x: factorized_to_original_movie_id(x))

            # Add movie titles
            df = df.merge(movies_data, left_on='MovieID', right_on='movieId')[['title', 'OriginalRating', 'PredictedRating']]

            # Print the comparison
            print(df)

            # Plot the comparison
            plt.figure(figsize=(10, 5))
            plt.scatter(df['OriginalRating'], df['PredictedRating'], color='blue', label='Data points')
            plt.plot([df['OriginalRating'].min(), df['OriginalRating'].max()],
                     [df['OriginalRating'].min(), df['OriginalRating'].max()], 'r--', label='Ideal line')
            plt.xlabel('Original Ratings (Normalized)')
            plt.ylabel('Predicted Ratings (Normalized)')
            plt.title(f'VAE - Original vs Predicted Ratings (Normalized) for User {user_id}')
            plt.legend()
            plt.grid(True)
            plt.show()
        else:
            print(f"User ID {user_id} not found.")

# Compare predicted and actual ratings for the specific user with normalized values
compare_user_ratings_normalized(3, model, device)
# Out:
#                                              title  OriginalRating
# 0                              Pulp Fiction (1994)        1.000000  \
# 1                                       Ran (1985)        1.000000
# 2                                   Gattaca (1997)        1.000000
# 3                              Moulin Rouge (2001)        0.555556
# 4    Lord of the Rings: The Two Towers, The (2002)        0.777778
# ..                                             ...             ...
# 642                       Blade Runner 2049 (2017)        0.888889
# 643                Star Wars: The Last Jedi (2017)        0.666667
# 644                                  Bright (2017)        0.555556
# 645                           Incredibles 2 (2018)        0.666667
# 646                              Deadpool 2 (2018)        0.888889
#
#      PredictedRating
# 0           0.826618
# 1           0.800677
# 2           0.736184
# 3           0.694591
# 4           0.801152
# ..               ...
# 642         0.768699
# 643         0.671719
# 644         0.549967
# 645         0.729955
# 646         0.752531
#
# [647 rows x 3 columns]

# %%
torch.save(model.state_dict(), 'movielens_VAE.pth')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to generate the completed matrix with predicted ratings
def generate_completed_matrix(model, user_item_matrix, device):
    model.eval()
    with torch.no_grad():
        # Convert the entire user-item matrix to a tensor and move it to the device
        user_item_tensor = torch.from_numpy(user_item_matrix.toarray()).float().to(device)
        
        # Pass the tensor through the model to get predicted ratings
        outputs = model(user_item_tensor)
        if isinstance(outputs, tuple):
            reconstructed_tensor = outputs[0]
        else:
            reconstructed_tensor = outputs
        
        # Move the reconstructed tensor back to CPU and convert to numpy array
        predicted_tensor = reconstructed_tensor.cpu().numpy()
        
        return predicted_tensor

# Generate the completed matrix with predicted ratings
completed_matrix = generate_completed_matrix(model, user_item_matrix, device)

# Flatten the completed matrix to get all predicted ratings
predicted_ratings = completed_matrix.flatten()

# Plot the distribution of the predicted ratings
plt.figure(figsize=(10, 6))
plt.hist(predicted_ratings, bins=30, edgecolor='black')
plt.title('Distribution of Predicted Ratings - VAE')
plt.xlabel('Predicted Ratings (Normalized)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
import torch
from torch import nn, optim
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import KFold
import numpy as np
import itertools
import random

# Define a simple VAE for reference
class VAE(nn.Module):
    def __init__(self, input_dim, hidden_dims, latent_dim):
        super(VAE, self).__init__()
        self.encoder = Encoder(input_dim, hidden_dims, latent_dim)
        self.decoder = Decoder(input_dim, hidden_dims, latent_dim)
    
    def reparameterize(self, mu, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return mu + eps * std
    
    def forward(self, x):
        mu, log_var = self.encoder(x)
        z = self.reparameterize(mu, log_var)
        reconstructed_x = self.decoder(z)
        return reconstructed_x, mu, log_var

# Define hyperparameter grid
hyperparameter_grid = {
    'learning_rate': [0.0001, 0.001, 0.01],
    'kl_weight': [0.1, 0.5, 1.0],
    'latent_dim': [64, 128, 256],
    'batch_size': [32, 64, 128]
}

# Define K-Fold Cross-Validation
kf = KFold(n_splits=3, shuffle=True, random_state=42)

# Function to evaluate model performance using k-fold cross-validation
def k_fold_cv(hyperparams, kf, train_dataset, device):
    input_dim = train_dataset[0][0].shape[0]  # Input dimension
    hidden_dims = [512, 256]  # Hidden dimensions

    learning_rate = hyperparams['learning_rate']
    kl_weight = hyperparams['kl_weight']
    latent_dim = hyperparams['latent_dim']
    batch_size = hyperparams['batch_size']

    val_losses = []

    for fold, (train_indices, val_indices) in enumerate(kf.split(np.arange(len(train_dataset)))):
        print(f"Processing fold {fold + 1}/{kf.n_splits} with hyperparameters: {hyperparams}")

        train_subset = Subset(train_dataset, train_indices)
        val_subset = Subset(train_dataset, val_indices)
        
        train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=batch_size)
        
        model = VAE(input_dim, hidden_dims, latent_dim).to(device)
        optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-5)
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

        # Train the model
        num_epochs = 10
        train_model(model, train_loader, val_loader, vae_loss_function, optimizer, scheduler, num_epochs, device)
        
        # Evaluate on validation set
        val_loss = evaluate_model(model, val_loader, vae_loss_function, device)
        val_losses.append(val_loss)

        print(f"Fold {fold + 1} Validation Loss: {val_loss:.4f}")

    return np.mean(val_losses)

# Perform grid search (but not for too many configurations)
# Define the number of random samples to draw from the hyperparameter grid
num_samples = 10

# Create a list of all possible hyperparameter combinations
all_combinations = list(itertools.product(*hyperparameter_grid.values()))

# Randomly select a subset of the hyperparameter combinations
random_combinations = random.sample(all_combinations, num_samples)

best_score = float('inf')
best_params = None

for param_combination in random_combinations:
    hyperparams = dict(zip(hyperparameter_grid.keys(), param_combination))
    print(f"Evaluating hyperparameters: {hyperparams}")
    avg_val_loss = k_fold_cv(hyperparams, kf, train_dataset, device)
    
    if avg_val_loss < best_score:
        best_score = avg_val_loss
        best_params = hyperparams

    print(f"Current best validation loss: {best_score:.4f} with hyperparameters: {best_params}")

print("Best hyperparameters:", best_params)
print("Best validation loss:", best_score)
# Out:
# Evaluating hyperparameters: {'learning_rate': 0.01, 'kl_weight': 0.5, 'latent_dim': 64, 'batch_size': 64}
# Processing fold 1/3 with hyperparameters: {'learning_rate': 0.01, 'kl_weight': 0.5, 'latent_dim': 64, 'batch_size': 64}
# Epoch [1/10], Batch [100/1016], Loss: 0.0609
# Epoch [1/10], Batch [200/1016], Loss: 0.0591
# Epoch [1/10], Batch [300/1016], Loss: 0.0522
# Epoch [1/10], Batch [400/1016], Loss: 0.0485
# Epoch [1/10], Batch [500/1016], Loss: 0.0577
# Epoch [1/10], Batch [600/1016], Loss: 0.0437
# Epoch [1/10], Batch [700/1016], Loss: 0.0467
# Epoch [1/10], Batch [800/1016], Loss: 0.0378
# Epoch [1/10], Batch [900/1016], Loss: 0.0489
# Epoch [1/10], Batch [1000/1016], Loss: 0.0409
# Epoch [1/10], Train Loss: 13.8073, Validation Loss: 0.0493
# Epoch [2/10], Batch [100/1016], Loss: 0.0498
# Epoch [2/10], Batch [200/1016], Loss: 0.0566
# Epoch [2/10], Batch [300/1016], Loss: 0.0561
# Epoch [2/10], Batch [400/1016], Loss: 0.2627
# Epoch [2/10], Batch [500/1016], Loss: 0.0630
# Epoch [2/10], Batch [600/1016], Loss: 0.0432
# Epoch [2/10], Batch [700/1016], Loss: 0.0532
# Epoch [2/10], Batch [800/1016], Loss: 0.0439
# Epoch [2/10], Batch [900/1016], Loss: 0.0384
# Epoch [2/10], Batch [1000/1016], Loss: 0.0936
# Epoch [2/10], Train Loss: 0.0807, Validation Loss: 0.2875
# Epoch [3/10], Batch [100/1016], Loss: 0.0469
# Epoch [3/10], Batch [200/1016], Loss: 0.0412
# Epoch [3/10], Batch [300/1016], Loss: 0.0545
# Epoch [3/10], Batch [400/1016], Loss: 0.0453
# Epoch [3/10], Batch [500/1016], Loss: 0.0523
# Epoch [3/10], Batch [600/1016], Loss: 0.0500
# Epoch [3/10], Batch [700/1016], Loss: 0.0454
# Epoch [3/10], Batch [800/1016], Loss: 0.0426
# Epoch [3/10], Batch [900/1016], Loss: 0.0481
# Epoch [3/10], Batch [1000/1016], Loss: 0.0420
# Epoch [3/10], Train Loss: 0.8484, Validation Loss: 0.0476
# Epoch [4/10], Batch [100/1016], Loss: 0.0505
# Epoch [4/10], Batch [200/1016], Loss: 0.0513
# Epoch [4/10], Batch [300/1016], Loss: 0.0431
# Epoch [4/10], Batch [400/1016], Loss: 0.0482
# Epoch [4/10], Batch [500/1016], Loss: 0.0458
# Epoch [4/10], Batch [600/1016], Loss: 0.0452
# Epoch [4/10], Batch [700/1016], Loss: 0.0346
# Epoch [4/10], Batch [800/1016], Loss: 0.0433
# Epoch [4/10], Batch [900/1016], Loss: 0.0414
# Epoch [4/10], Batch [1000/1016], Loss: 0.1190
# Epoch [4/10], Train Loss: 42.3161, Validation Loss: 0.0859
# Epoch [5/10], Batch [100/1016], Loss: 0.0428
# Epoch [5/10], Batch [200/1016], Loss: 0.0456
# Epoch [5/10], Batch [300/1016], Loss: 0.0408
# Epoch [5/10], Batch [400/1016], Loss: 0.0572
# Epoch [5/10], Batch [500/1016], Loss: 0.0496
# Epoch [5/10], Batch [600/1016], Loss: 0.0411
# Epoch [5/10], Batch [700/1016], Loss: 0.0484
# Epoch [5/10], Batch [800/1016], Loss: 0.0631
# Epoch [5/10], Batch [900/1016], Loss: 0.0450
# Epoch [5/10], Batch [1000/1016], Loss: 0.0531
# Epoch [5/10], Train Loss: 0.0484, Validation Loss: 0.0478
# Epoch [6/10], Batch [100/1016], Loss: 0.0533
# Epoch [6/10], Batch [200/1016], Loss: 0.0474
# Epoch [6/10], Batch [300/1016], Loss: 0.0470
# Epoch [6/10], Batch [400/1016], Loss: 0.0432
# Epoch [6/10], Batch [500/1016], Loss: 0.0440
# Epoch [6/10], Batch [600/1016], Loss: 0.0729
# Epoch [6/10], Batch [700/1016], Loss: 0.0457
# Epoch [6/10], Batch [800/1016], Loss: 0.0445
# Epoch [6/10], Batch [900/1016], Loss: 0.0410
# Epoch [6/10], Batch [1000/1016], Loss: 0.0543
# Epoch [6/10], Train Loss: 0.0484, Validation Loss: 0.0477
# Epoch [7/10], Batch [100/1016], Loss: 0.0475
# Epoch [7/10], Batch [200/1016], Loss: 0.0510
# Epoch [7/10], Batch [300/1016], Loss: 0.0491
# Epoch [7/10], Batch [400/1016], Loss: 0.0468
# Epoch [7/10], Batch [500/1016], Loss: 0.0507
# Epoch [7/10], Batch [600/1016], Loss: 0.0438
# Epoch [7/10], Batch [700/1016], Loss: 0.0456
# Epoch [7/10], Batch [800/1016], Loss: 0.0400
# Epoch [7/10], Batch [900/1016], Loss: 0.0469
# Epoch [7/10], Batch [1000/1016], Loss: 0.0466
# Epoch [7/10], Train Loss: 0.0485, Validation Loss: 0.0484
# Epoch [8/10], Batch [100/1016], Loss: 0.0466
# Epoch [8/10], Batch [200/1016], Loss: 0.0491
# Epoch [8/10], Batch [300/1016], Loss: 0.0434
# Epoch [8/10], Batch [400/1016], Loss: 0.0578
# Epoch [8/10], Batch [500/1016], Loss: 0.0450
# Epoch [8/10], Batch [600/1016], Loss: 0.0617
# Epoch [8/10], Batch [700/1016], Loss: 0.0493
# Epoch [8/10], Batch [800/1016], Loss: 0.0543
# Epoch [8/10], Batch [900/1016], Loss: 0.0549
# Epoch [8/10], Batch [1000/1016], Loss: 0.0524
# Epoch [8/10], Train Loss: 0.0493, Validation Loss: 0.0488
# Early stopping at epoch 8
# Fold 1 Validation Loss: 0.0486
# Processing fold 2/3 with hyperparameters: {'learning_rate': 0.01, 'kl_weight': 0.5, 'latent_dim': 64, 'batch_size': 64}
# Epoch [1/10], Batch [100/1016], Loss: 0.0764
# Epoch [1/10], Batch [200/1016], Loss: 0.4074
# Epoch [1/10], Batch [300/1016], Loss: 0.0581
# Epoch [1/10], Batch [400/1016], Loss: 0.0668
# Epoch [1/10], Batch [500/1016], Loss: 0.0615
# Epoch [1/10], Batch [600/1016], Loss: 0.0595
# Epoch [1/10], Batch [700/1016], Loss: 0.0654
# Epoch [1/10], Batch [800/1016], Loss: 0.0725
# Epoch [1/10], Batch [900/1016], Loss: 0.0607
# Epoch [1/10], Batch [1000/1016], Loss: 0.0511
# Epoch [1/10], Train Loss: 47856.1240, Validation Loss: 0.0550
# Epoch [2/10], Batch [100/1016], Loss: 0.2034
# Epoch [2/10], Batch [200/1016], Loss: 0.1097
# Epoch [2/10], Batch [300/1016], Loss: 0.2738
# Epoch [2/10], Batch [400/1016], Loss: 0.1164
# Epoch [2/10], Batch [500/1016], Loss: 0.0648
# Epoch [2/10], Batch [600/1016], Loss: 0.0513
# Epoch [2/10], Batch [700/1016], Loss: 0.0490
# Epoch [2/10], Batch [800/1016], Loss: 0.0653
# Epoch [2/10], Batch [900/1016], Loss: 0.0490
# Epoch [2/10], Batch [1000/1016], Loss: 0.0532
# Epoch [2/10], Train Loss: 2.0954, Validation Loss: 0.0551
# Epoch [3/10], Batch [100/1016], Loss: 0.0442
# Epoch [3/10], Batch [200/1016], Loss: 0.0492
# Epoch [3/10], Batch [300/1016], Loss: 0.0622
# Epoch [3/10], Batch [400/1016], Loss: 0.0482
# Epoch [3/10], Batch [500/1016], Loss: 0.0914
# Epoch [3/10], Batch [600/1016], Loss: 0.1019
# Epoch [3/10], Batch [700/1016], Loss: 0.0428
# Epoch [3/10], Batch [800/1016], Loss: 0.0422
# Epoch [3/10], Batch [900/1016], Loss: 0.0408
# Epoch [3/10], Batch [1000/1016], Loss: 0.0994
# Epoch [3/10], Train Loss: 0.1530, Validation Loss: 0.0630
# Epoch [4/10], Batch [100/1016], Loss: 0.3837
# Epoch [4/10], Batch [200/1016], Loss: 0.0553
# Epoch [4/10], Batch [300/1016], Loss: 0.0623
# Epoch [4/10], Batch [400/1016], Loss: 0.0571
# Epoch [4/10], Batch [500/1016], Loss: 0.0430
# Epoch [4/10], Batch [600/1016], Loss: 0.0504
# Epoch [4/10], Batch [700/1016], Loss: 0.0393
# Epoch [4/10], Batch [800/1016], Loss: 0.0496
# Epoch [4/10], Batch [900/1016], Loss: 0.0438
# Epoch [4/10], Batch [1000/1016], Loss: 0.0437
# Epoch [4/10], Train Loss: 0.0732, Validation Loss: 0.0512
# Epoch [5/10], Batch [100/1016], Loss: 0.1079
# Epoch [5/10], Batch [200/1016], Loss: 0.0652
# Epoch [5/10], Batch [300/1016], Loss: 0.0374
# Epoch [5/10], Batch [400/1016], Loss: 0.0543
# Epoch [5/10], Batch [500/1016], Loss: 0.0507
# Epoch [5/10], Batch [600/1016], Loss: 0.0853
# Epoch [5/10], Batch [700/1016], Loss: 0.0487
# Epoch [5/10], Batch [800/1016], Loss: 0.0498
# Epoch [5/10], Batch [900/1016], Loss: 0.0464
# Epoch [5/10], Batch [1000/1016], Loss: 0.0612
# Epoch [5/10], Train Loss: 0.0523, Validation Loss: 0.0496
# Epoch [6/10], Batch [100/1016], Loss: 0.0611
# Epoch [6/10], Batch [200/1016], Loss: 0.0483
# Epoch [6/10], Batch [300/1016], Loss: 0.0534
# Epoch [6/10], Batch [400/1016], Loss: 0.0673
# Epoch [6/10], Batch [500/1016], Loss: 0.0443
# Epoch [6/10], Batch [600/1016], Loss: 0.0601
# Epoch [6/10], Batch [700/1016], Loss: 0.0536
# Epoch [6/10], Batch [800/1016], Loss: 0.0651
# Epoch [6/10], Batch [900/1016], Loss: 0.1167
# Epoch [6/10], Batch [1000/1016], Loss: 0.0585
# Epoch [6/10], Train Loss: 0.0549, Validation Loss: 0.0487
# Epoch [7/10], Batch [100/1016], Loss: 0.0498
# Epoch [7/10], Batch [200/1016], Loss: 0.0498
# Epoch [7/10], Batch [300/1016], Loss: 0.0435
# Epoch [7/10], Batch [400/1016], Loss: 0.0400
# Epoch [7/10], Batch [500/1016], Loss: 0.0955
# Epoch [7/10], Batch [600/1016], Loss: 0.0404
# Epoch [7/10], Batch [700/1016], Loss: 0.0748
# Epoch [7/10], Batch [800/1016], Loss: 0.0533
# Epoch [7/10], Batch [900/1016], Loss: 0.0577
# Epoch [7/10], Batch [1000/1016], Loss: 0.0555
# Epoch [7/10], Train Loss: 0.0549, Validation Loss: 0.0496
# Epoch [8/10], Batch [100/1016], Loss: 0.0497
# Epoch [8/10], Batch [200/1016], Loss: 0.0459
# Epoch [8/10], Batch [300/1016], Loss: 0.0567
# Epoch [8/10], Batch [400/1016], Loss: 0.0589
# Epoch [8/10], Batch [500/1016], Loss: 0.0462
# Epoch [8/10], Batch [600/1016], Loss: 0.1378
# Epoch [8/10], Batch [700/1016], Loss: 0.0455
# Epoch [8/10], Batch [800/1016], Loss: 0.0707
# Epoch [8/10], Batch [900/1016], Loss: 0.0610
# Epoch [8/10], Batch [1000/1016], Loss: 3.5159
# Epoch [8/10], Train Loss: 0.7502, Validation Loss: 0.6122
# Epoch [9/10], Batch [100/1016], Loss: 0.0573
# Epoch [9/10], Batch [200/1016], Loss: 0.0566
# Epoch [9/10], Batch [300/1016], Loss: 0.0590
# Epoch [9/10], Batch [400/1016], Loss: 0.0576
# Epoch [9/10], Batch [500/1016], Loss: 0.3430
# Epoch [9/10], Batch [600/1016], Loss: 4.3955
# Epoch [9/10], Batch [700/1016], Loss: 0.1370
# Epoch [9/10], Batch [800/1016], Loss: 0.0568
# Epoch [9/10], Batch [900/1016], Loss: 10.1741
# Epoch [9/10], Batch [1000/1016], Loss: 0.0625
# Epoch [9/10], Train Loss: 0.6564, Validation Loss: 0.0924
# Epoch [10/10], Batch [100/1016], Loss: 0.0642
# Epoch [10/10], Batch [200/1016], Loss: 0.0487
# Epoch [10/10], Batch [300/1016], Loss: 0.9580
# Epoch [10/10], Batch [400/1016], Loss: 0.0812
# Epoch [10/10], Batch [500/1016], Loss: 16.3478
# Epoch [10/10], Batch [600/1016], Loss: 0.0527
# Epoch [10/10], Batch [700/1016], Loss: 0.0565
# Epoch [10/10], Batch [800/1016], Loss: 0.0447
# Epoch [10/10], Batch [900/1016], Loss: 0.0462
# Epoch [10/10], Batch [1000/1016], Loss: 0.0463
# Epoch [10/10], Train Loss: 74866886.8697, Validation Loss: 0.0500
# Fold 2 Validation Loss: 0.0501
# Processing fold 3/3 with hyperparameters: {'learning_rate': 0.01, 'kl_weight': 0.5, 'latent_dim': 64, 'batch_size': 64}
# Epoch [1/10], Batch [100/1016], Loss: 0.0851
# Epoch [1/10], Batch [200/1016], Loss: 0.0490
# Epoch [1/10], Batch [300/1016], Loss: 0.0452
# Epoch [1/10], Batch [400/1016], Loss: 0.0460
# Epoch [1/10], Batch [500/1016], Loss: 0.0665
# Epoch [1/10], Batch [600/1016], Loss: 0.0506
# Epoch [1/10], Batch [700/1016], Loss: 0.0674
# Epoch [1/10], Batch [800/1016], Loss: 0.0414
# Epoch [1/10], Batch [900/1016], Loss: 0.0489
# Epoch [1/10], Batch [1000/1016], Loss: 0.0447
# Epoch [1/10], Train Loss: 19.6116, Validation Loss: 0.0502
# Epoch [2/10], Batch [100/1016], Loss: 0.0630
# Epoch [2/10], Batch [200/1016], Loss: 0.0519
# Epoch [2/10], Batch [300/1016], Loss: 0.0505
# Epoch [2/10], Batch [400/1016], Loss: 0.0385
# Epoch [2/10], Batch [500/1016], Loss: 0.0454
# Epoch [2/10], Batch [600/1016], Loss: 0.0481
# Epoch [2/10], Batch [700/1016], Loss: 0.0448
# Epoch [2/10], Batch [800/1016], Loss: 0.0499
# Epoch [2/10], Batch [900/1016], Loss: 0.0406
# Epoch [2/10], Batch [1000/1016], Loss: 0.0441
# Epoch [2/10], Train Loss: 0.0724, Validation Loss: 0.0485
# Epoch [3/10], Batch [100/1016], Loss: 0.0470
# Epoch [3/10], Batch [200/1016], Loss: 0.0448
# Epoch [3/10], Batch [300/1016], Loss: 0.0785
# Epoch [3/10], Batch [400/1016], Loss: 0.0514
# Epoch [3/10], Batch [500/1016], Loss: 0.0493
# Epoch [3/10], Batch [600/1016], Loss: 0.0522
# Epoch [3/10], Batch [700/1016], Loss: 0.0518
# Epoch [3/10], Batch [800/1016], Loss: 0.0483
# Epoch [3/10], Batch [900/1016], Loss: 0.0561
# Epoch [3/10], Batch [1000/1016], Loss: 0.0447
# Epoch [3/10], Train Loss: 0.1522, Validation Loss: 0.0494
# Epoch [4/10], Batch [100/1016], Loss: 0.0457
# Epoch [4/10], Batch [200/1016], Loss: 0.0554
# Epoch [4/10], Batch [300/1016], Loss: 0.0451
# Epoch [4/10], Batch [400/1016], Loss: 0.0569
# Epoch [4/10], Batch [500/1016], Loss: 0.0474
# Epoch [4/10], Batch [600/1016], Loss: 0.0556
# Epoch [4/10], Batch [700/1016], Loss: 0.0449
# Epoch [4/10], Batch [800/1016], Loss: 0.0505
# Epoch [4/10], Batch [900/1016], Loss: 0.0431
# Epoch [4/10], Batch [1000/1016], Loss: 0.0547
# Epoch [4/10], Train Loss: 0.0807, Validation Loss: 0.0482
# Epoch [5/10], Batch [100/1016], Loss: 0.0440
# Epoch [5/10], Batch [200/1016], Loss: 0.0497
# Epoch [5/10], Batch [300/1016], Loss: 0.0515
# Epoch [5/10], Batch [400/1016], Loss: 0.0478
# Epoch [5/10], Batch [500/1016], Loss: 0.0505
# Epoch [5/10], Batch [600/1016], Loss: 0.0424
# Epoch [5/10], Batch [700/1016], Loss: 0.0400
# Epoch [5/10], Batch [800/1016], Loss: 0.0626
# Epoch [5/10], Batch [900/1016], Loss: 0.0392
# Epoch [5/10], Batch [1000/1016], Loss: 0.0506
# Epoch [5/10], Train Loss: 0.0518, Validation Loss: 0.0473
# Epoch [6/10], Batch [100/1016], Loss: 0.0427
# Epoch [6/10], Batch [200/1016], Loss: 0.0436
# Epoch [6/10], Batch [300/1016], Loss: 0.0605
# Epoch [6/10], Batch [400/1016], Loss: 0.0535
# Epoch [6/10], Batch [500/1016], Loss: 0.0472
# Epoch [6/10], Batch [600/1016], Loss: 0.0557
# Epoch [6/10], Batch [700/1016], Loss: 0.0410
# Epoch [6/10], Batch [800/1016], Loss: 0.0486
# Epoch [6/10], Batch [900/1016], Loss: 0.0608
# Epoch [6/10], Batch [1000/1016], Loss: 0.0552
# Epoch [6/10], Train Loss: 0.0485, Validation Loss: 0.0489
# Epoch [7/10], Batch [100/1016], Loss: 0.0469
# Epoch [7/10], Batch [200/1016], Loss: 0.0519
# Epoch [7/10], Batch [300/1016], Loss: 0.0495
# Epoch [7/10], Batch [400/1016], Loss: 0.0473
# Epoch [7/10], Batch [500/1016], Loss: 0.0462
# Epoch [7/10], Batch [600/1016], Loss: 0.0560
# Epoch [7/10], Batch [700/1016], Loss: 0.0453
# Epoch [7/10], Batch [800/1016], Loss: 0.0423
# Epoch [7/10], Batch [900/1016], Loss: 0.0587
# Epoch [7/10], Batch [1000/1016], Loss: 0.0501
# Epoch [7/10], Train Loss: 0.0488, Validation Loss: 0.0481
# Epoch [8/10], Batch [100/1016], Loss: 0.0551
# Epoch [8/10], Batch [200/1016], Loss: 0.0506
# Epoch [8/10], Batch [300/1016], Loss: 0.0627
# Epoch [8/10], Batch [400/1016], Loss: 0.0453
# Epoch [8/10], Batch [500/1016], Loss: 0.0494
# Epoch [8/10], Batch [600/1016], Loss: 0.0425
# Epoch [8/10], Batch [700/1016], Loss: 0.0414
# Epoch [8/10], Batch [800/1016], Loss: 0.0558
# Epoch [8/10], Batch [900/1016], Loss: 0.0554
# Epoch [8/10], Batch [1000/1016], Loss: 0.0547
# Epoch [8/10], Train Loss: 0.0490, Validation Loss: 0.0487
# Epoch [9/10], Batch [100/1016], Loss: 0.0574
# Epoch [9/10], Batch [200/1016], Loss: 0.0423
# Epoch [9/10], Batch [300/1016], Loss: 0.0592
# Epoch [9/10], Batch [400/1016], Loss: 0.0454
# Epoch [9/10], Batch [500/1016], Loss: 0.0432
# Epoch [9/10], Batch [600/1016], Loss: 0.0410
# Epoch [9/10], Batch [700/1016], Loss: 0.0505
# Epoch [9/10], Batch [800/1016], Loss: 0.0485
# Epoch [9/10], Batch [900/1016], Loss: 0.0470
# Epoch [9/10], Batch [1000/1016], Loss: 0.0511
# Epoch [9/10], Train Loss: 0.0491, Validation Loss: 0.0480
# Epoch [10/10], Batch [100/1016], Loss: 0.0463
# Epoch [10/10], Batch [200/1016], Loss: 0.0436
# Epoch [10/10], Batch [300/1016], Loss: 0.0480
# Epoch [10/10], Batch [400/1016], Loss: 0.0451
# Epoch [10/10], Batch [500/1016], Loss: 0.0516
# Epoch [10/10], Batch [600/1016], Loss: 0.0418
# Epoch [10/10], Batch [700/1016], Loss: 0.0464
# Epoch [10/10], Batch [800/1016], Loss: 0.0489
# Epoch [10/10], Batch [900/1016], Loss: 0.0440
# Epoch [10/10], Batch [1000/1016], Loss: 0.0473
# Epoch [10/10], Train Loss: 0.0514, Validation Loss: 0.0484
# Early stopping at epoch 10
# Fold 3 Validation Loss: 0.0484
# Current best validation loss: 0.0490 with hyperparameters: {'learning_rate': 0.01, 'kl_weight': 0.5, 'latent_dim': 64, 'batch_size': 64}
# Evaluating hyperparameters: {'learning_rate': 0.0001, 'kl_weight': 0.5, 'latent_dim': 64, 'batch_size': 128}
# Processing fold 1/3 with hyperparameters: {'learning_rate': 0.0001, 'kl_weight': 0.5, 'latent_dim': 64, 'batch_size': 128}
# Epoch [1/10], Batch [100/508], Loss: 0.3104
# Epoch [1/10], Batch [200/508], Loss: 0.1692
# Epoch [1/10], Batch [300/508], Loss: 0.1288
# Epoch [1/10], Batch [400/508], Loss: 0.1013
# Epoch [1/10], Batch [500/508], Loss: 0.0938
# Epoch [1/10], Train Loss: 0.4728, Validation Loss: 0.0944
# Epoch [2/10], Batch [100/508], Loss: 0.0751
# Epoch [2/10], Batch [200/508], Loss: 0.0785
# Epoch [2/10], Batch [300/508], Loss: 0.0715
# Epoch [2/10], Batch [400/508], Loss: 0.0667
# Epoch [2/10], Batch [500/508], Loss: 0.0642
# Epoch [2/10], Train Loss: 0.0756, Validation Loss: 0.0672
# Epoch [3/10], Batch [100/508], Loss: 0.0553
# Epoch [3/10], Batch [200/508], Loss: 0.0565
# Epoch [3/10], Batch [300/508], Loss: 0.0509
# Epoch [3/10], Batch [400/508], Loss: 0.0568
# Epoch [3/10], Batch [500/508], Loss: 0.0491
# Epoch [3/10], Train Loss: 0.0596, Validation Loss: 0.0576
# Epoch [4/10], Batch [100/508], Loss: 0.0536
# Epoch [4/10], Batch [200/508], Loss: 0.0533
# Epoch [4/10], Batch [300/508], Loss: 0.0483
# Epoch [4/10], Batch [400/508], Loss: 0.0537
# Epoch [4/10], Batch [500/508], Loss: 0.0540
# Epoch [4/10], Train Loss: 0.0539, Validation Loss: 0.0530
# Epoch [5/10], Batch [100/508], Loss: 0.0570
# Epoch [5/10], Batch [200/508], Loss: 0.0629
# Epoch [5/10], Batch [300/508], Loss: 0.0567
# Epoch [5/10], Batch [400/508], Loss: 0.0540
# Epoch [5/10], Batch [500/508], Loss: 0.0556
# Epoch [5/10], Train Loss: 0.0511, Validation Loss: 0.0505
# Epoch [6/10], Batch [100/508], Loss: 0.0487
# Epoch [6/10], Batch [200/508], Loss: 0.0557
# Epoch [6/10], Batch [300/508], Loss: 0.0531
# Epoch [6/10], Batch [400/508], Loss: 0.0436
# Epoch [6/10], Batch [500/508], Loss: 0.0444
# Epoch [6/10], Train Loss: 0.0495, Validation Loss: 0.0494
# Epoch [7/10], Batch [100/508], Loss: 0.0547
# Epoch [7/10], Batch [200/508], Loss: 0.0443
# Epoch [7/10], Batch [300/508], Loss: 0.0544
# Epoch [7/10], Batch [400/508], Loss: 0.0472
# Epoch [7/10], Batch [500/508], Loss: 0.0418
# Epoch [7/10], Train Loss: 0.0487, Validation Loss: 0.0483
# Epoch [8/10], Batch [100/508], Loss: 0.0383
# Epoch [8/10], Batch [200/508], Loss: 0.0454
# Epoch [8/10], Batch [300/508], Loss: 0.0485
# Epoch [8/10], Batch [400/508], Loss: 0.0502
# Epoch [8/10], Batch [500/508], Loss: 0.0465
# Epoch [8/10], Train Loss: 0.0480, Validation Loss: 0.0476
# Epoch [9/10], Batch [100/508], Loss: 0.0415
# Epoch [9/10], Batch [200/508], Loss: 0.0466
# Epoch [9/10], Batch [300/508], Loss: 0.0483
# Epoch [9/10], Batch [400/508], Loss: 0.0505
# Epoch [9/10], Batch [500/508], Loss: 0.0440
# Epoch [9/10], Train Loss: 0.0475, Validation Loss: 0.0473
# Epoch [10/10], Batch [100/508], Loss: 0.0459
# Epoch [10/10], Batch [200/508], Loss: 0.0486
# Epoch [10/10], Batch [300/508], Loss: 0.0431
# Epoch [10/10], Batch [400/508], Loss: 0.0446
# Epoch [10/10], Batch [500/508], Loss: 0.0484
# Epoch [10/10], Train Loss: 0.0471, Validation Loss: 0.0470
# Fold 1 Validation Loss: 0.0468
# Processing fold 2/3 with hyperparameters: {'learning_rate': 0.0001, 'kl_weight': 0.5, 'latent_dim': 64, 'batch_size': 128}
# Epoch [1/10], Batch [100/508], Loss: 0.2864
# Epoch [1/10], Batch [200/508], Loss: 0.1664
# Epoch [1/10], Batch [300/508], Loss: 0.1056
# Epoch [1/10], Batch [400/508], Loss: 0.1045
# Epoch [1/10], Batch [500/508], Loss: 0.0875
# Epoch [1/10], Train Loss: 0.4590, Validation Loss: 0.0900
# Epoch [2/10], Batch [100/508], Loss: 0.0701
# Epoch [2/10], Batch [200/508], Loss: 0.0734
# Epoch [2/10], Batch [300/508], Loss: 0.0651
# Epoch [2/10], Batch [400/508], Loss: 0.0594
# Epoch [2/10], Batch [500/508], Loss: 0.0618
# Epoch [2/10], Train Loss: 0.0724, Validation Loss: 0.0648
# Epoch [3/10], Batch [100/508], Loss: 0.0581
# Epoch [3/10], Batch [200/508], Loss: 0.0500
# Epoch [3/10], Batch [300/508], Loss: 0.0693
# Epoch [3/10], Batch [400/508], Loss: 0.0516
# Epoch [3/10], Batch [500/508], Loss: 0.0574
# Epoch [3/10], Train Loss: 0.0576, Validation Loss: 0.0553
# Epoch [4/10], Batch [100/508], Loss: 0.0491
# Epoch [4/10], Batch [200/508], Loss: 0.0497
# Epoch [4/10], Batch [300/508], Loss: 0.0516
# Epoch [4/10], Batch [400/508], Loss: 0.0468
# Epoch [4/10], Batch [500/508], Loss: 0.0495
# Epoch [4/10], Train Loss: 0.0520, Validation Loss: 0.0513
# Epoch [5/10], Batch [100/508], Loss: 0.0526
# Epoch [5/10], Batch [200/508], Loss: 0.0502
# Epoch [5/10], Batch [300/508], Loss: 0.0446
# Epoch [5/10], Batch [400/508], Loss: 0.0444
# Epoch [5/10], Batch [500/508], Loss: 0.0466
# Epoch [5/10], Train Loss: 0.0499, Validation Loss: 0.0498
# Epoch [6/10], Batch [100/508], Loss: 0.0509
# Epoch [6/10], Batch [200/508], Loss: 0.0473
# Epoch [6/10], Batch [300/508], Loss: 0.0489
# Epoch [6/10], Batch [400/508], Loss: 0.0621
# Epoch [6/10], Batch [500/508], Loss: 0.0430
# Epoch [6/10], Train Loss: 0.0489, Validation Loss: 0.0489
# Epoch [7/10], Batch [100/508], Loss: 0.0433
# Epoch [7/10], Batch [200/508], Loss: 0.0447
# Epoch [7/10], Batch [300/508], Loss: 0.0421
# Epoch [7/10], Batch [400/508], Loss: 0.0501
# Epoch [7/10], Batch [500/508], Loss: 0.0456
# Epoch [7/10], Train Loss: 0.0481, Validation Loss: 0.0482
# Epoch [8/10], Batch [100/508], Loss: 0.0490
# Epoch [8/10], Batch [200/508], Loss: 0.0466
# Epoch [8/10], Batch [300/508], Loss: 0.0489
# Epoch [8/10], Batch [400/508], Loss: 0.0469
# Epoch [8/10], Batch [500/508], Loss: 0.0497
# Epoch [8/10], Train Loss: 0.0477, Validation Loss: 0.0477
# Epoch [9/10], Batch [100/508], Loss: 0.0488
# Epoch [9/10], Batch [200/508], Loss: 0.0446
# Epoch [9/10], Batch [300/508], Loss: 0.0391
# Epoch [9/10], Batch [400/508], Loss: 0.0450
# Epoch [9/10], Batch [500/508], Loss: 0.0486
# Epoch [9/10], Train Loss: 0.0472, Validation Loss: 0.0473
# Epoch [10/10], Batch [100/508], Loss: 0.0429
# Epoch [10/10], Batch [200/508], Loss: 0.0495
# Epoch [10/10], Batch [300/508], Loss: 0.0495
# Epoch [10/10], Batch [400/508], Loss: 0.0487
# Epoch [10/10], Batch [500/508], Loss: 0.0474
# Epoch [10/10], Train Loss: 0.0471, Validation Loss: 0.0471
# Fold 2 Validation Loss: 0.0470
# Processing fold 3/3 with hyperparameters: {'learning_rate': 0.0001, 'kl_weight': 0.5, 'latent_dim': 64, 'batch_size': 128}
# Epoch [1/10], Batch [100/508], Loss: 0.3222
# Epoch [1/10], Batch [200/508], Loss: 0.1593
# Epoch [1/10], Batch [300/508], Loss: 0.1243
# Epoch [1/10], Batch [400/508], Loss: 0.0989
# Epoch [1/10], Batch [500/508], Loss: 0.0893
# Epoch [1/10], Train Loss: 0.4563, Validation Loss: 0.0901
# Epoch [2/10], Batch [100/508], Loss: 0.0739
# Epoch [2/10], Batch [200/508], Loss: 0.0800
# Epoch [2/10], Batch [300/508], Loss: 0.0645
# Epoch [2/10], Batch [400/508], Loss: 0.0651
# Epoch [2/10], Batch [500/508], Loss: 0.0624
# Epoch [2/10], Train Loss: 0.0718, Validation Loss: 0.0631
# Epoch [3/10], Batch [100/508], Loss: 0.0600
# Epoch [3/10], Batch [200/508], Loss: 0.0675
# Epoch [3/10], Batch [300/508], Loss: 0.0516
# Epoch [3/10], Batch [400/508], Loss: 0.0513
# Epoch [3/10], Batch [500/508], Loss: 0.0557
# Epoch [3/10], Train Loss: 0.0573, Validation Loss: 0.0547
# Epoch [4/10], Batch [100/508], Loss: 0.0521
# Epoch [4/10], Batch [200/508], Loss: 0.0497
# Epoch [4/10], Batch [300/508], Loss: 0.0561
# Epoch [4/10], Batch [400/508], Loss: 0.0500
# Epoch [4/10], Batch [500/508], Loss: 0.0487
# Epoch [4/10], Train Loss: 0.0523, Validation Loss: 0.0517
# Epoch [5/10], Batch [100/508], Loss: 0.0524
# Epoch [5/10], Batch [200/508], Loss: 0.0523
# Epoch [5/10], Batch [300/508], Loss: 0.0531
# Epoch [5/10], Batch [400/508], Loss: 0.0563
# Epoch [5/10], Batch [500/508], Loss: 0.0438
# Epoch [5/10], Train Loss: 0.0504, Validation Loss: 0.0499
# Epoch [6/10], Batch [100/508], Loss: 0.0515
# Epoch [6/10], Batch [200/508], Loss: 0.0496
# Epoch [6/10], Batch [300/508], Loss: 0.0460
# Epoch [6/10], Batch [400/508], Loss: 0.0487
# Epoch [6/10], Batch [500/508], Loss: 0.0500
# Epoch [6/10], Train Loss: 0.0492, Validation Loss: 0.0491
# Epoch [7/10], Batch [100/508], Loss: 0.0508
# Epoch [7/10], Batch [200/508], Loss: 0.0460
# Epoch [7/10], Batch [300/508], Loss: 0.0526
# Epoch [7/10], Batch [400/508], Loss: 0.0494
# Epoch [7/10], Batch [500/508], Loss: 0.0478
# Epoch [7/10], Train Loss: 0.0484, Validation Loss: 0.0484
# Epoch [8/10], Batch [100/508], Loss: 0.0413
# Epoch [8/10], Batch [200/508], Loss: 0.0521
# Epoch [8/10], Batch [300/508], Loss: 0.0447
# Epoch [8/10], Batch [400/508], Loss: 0.0506
# Epoch [8/10], Batch [500/508], Loss: 0.0483
# Epoch [8/10], Train Loss: 0.0477, Validation Loss: 0.0479
# Epoch [9/10], Batch [100/508], Loss: 0.0530
# Epoch [9/10], Batch [200/508], Loss: 0.0420
# Epoch [9/10], Batch [300/508], Loss: 0.0532
# Epoch [9/10], Batch [400/508], Loss: 0.0520
# Epoch [9/10], Batch [500/508], Loss: 0.0464
# Epoch [9/10], Train Loss: 0.0474, Validation Loss: 0.0474
# Epoch [10/10], Batch [100/508], Loss: 0.0476
# Epoch [10/10], Batch [200/508], Loss: 0.0401
# Epoch [10/10], Batch [300/508], Loss: 0.0473
# Epoch [10/10], Batch [400/508], Loss: 0.0531
# Epoch [10/10], Batch [500/508], Loss: 0.0436
# Epoch [10/10], Train Loss: 0.0470, Validation Loss: 0.0472
# Fold 3 Validation Loss: 0.0472
# Current best validation loss: 0.0470 with hyperparameters: {'learning_rate': 0.0001, 'kl_weight': 0.5, 'latent_dim': 64, 'batch_size': 128}
# Evaluating hyperparameters: {'learning_rate': 0.01, 'kl_weight': 0.5, 'latent_dim': 256, 'batch_size': 32}
# Processing fold 1/3 with hyperparameters: {'learning_rate': 0.01, 'kl_weight': 0.5, 'latent_dim': 256, 'batch_size': 32}
# Epoch [1/10], Batch [100/2032], Loss: 0.2848
# Epoch [1/10], Batch [200/2032], Loss: 0.0616
# Epoch [1/10], Batch [300/2032], Loss: 0.0494
# Epoch [1/10], Batch [400/2032], Loss: 0.0519
# Epoch [1/10], Batch [500/2032], Loss: 0.0565
# Epoch [1/10], Batch [600/2032], Loss: 0.0638
# Epoch [1/10], Batch [700/2032], Loss: 0.1030
# Epoch [1/10], Batch [800/2032], Loss: 0.0501
# Epoch [1/10], Batch [900/2032], Loss: 0.0492
# Epoch [1/10], Batch [1000/2032], Loss: 0.0493
# Epoch [1/10], Batch [1100/2032], Loss: 0.0511
# Epoch [1/10], Batch [1200/2032], Loss: 0.0483
# Epoch [1/10], Batch [1300/2032], Loss: 0.0473
# Epoch [1/10], Batch [1400/2032], Loss: 0.0533
# Epoch [1/10], Batch [1500/2032], Loss: 0.0409
# Epoch [1/10], Batch [1600/2032], Loss: 0.0382
# Epoch [1/10], Batch [1700/2032], Loss: 0.0537
# Epoch [1/10], Batch [1800/2032], Loss: 0.0507
# Epoch [1/10], Batch [1900/2032], Loss: 0.0424
# Epoch [1/10], Batch [2000/2032], Loss: 0.0540
# Epoch [1/10], Train Loss: 3.8178, Validation Loss: 0.0609
# Epoch [2/10], Batch [100/2032], Loss: 0.0545
# Epoch [2/10], Batch [200/2032], Loss: 0.2154
# Epoch [2/10], Batch [300/2032], Loss: 0.0532
# Epoch [2/10], Batch [400/2032], Loss: 0.0612
# Epoch [2/10], Batch [500/2032], Loss: 0.0442
# Epoch [2/10], Batch [600/2032], Loss: 0.0627
# Epoch [2/10], Batch [700/2032], Loss: 0.0536
# Epoch [2/10], Batch [800/2032], Loss: 0.0433
# Epoch [2/10], Batch [900/2032], Loss: 0.0545
# Epoch [2/10], Batch [1000/2032], Loss: 0.0489
# Epoch [2/10], Batch [1100/2032], Loss: 0.0492
# Epoch [2/10], Batch [1200/2032], Loss: 0.0463
# Epoch [2/10], Batch [1300/2032], Loss: 0.0916
# Epoch [2/10], Batch [1400/2032], Loss: 0.0389
# Epoch [2/10], Batch [1500/2032], Loss: 0.0425
# Epoch [2/10], Batch [1600/2032], Loss: 0.0399
# Epoch [2/10], Batch [1700/2032], Loss: 0.0508
# Epoch [2/10], Batch [1800/2032], Loss: 0.0547
# Epoch [2/10], Batch [1900/2032], Loss: 0.1049
# Epoch [2/10], Batch [2000/2032], Loss: 0.3362
# Epoch [2/10], Train Loss: 0.6618, Validation Loss: 0.3330
# Epoch [3/10], Batch [100/2032], Loss: 0.0476
# Epoch [3/10], Batch [200/2032], Loss: 0.0571
# Epoch [3/10], Batch [300/2032], Loss: 0.0341
# Epoch [3/10], Batch [400/2032], Loss: 0.0518
# Epoch [3/10], Batch [500/2032], Loss: 0.0446
# Epoch [3/10], Batch [600/2032], Loss: 0.0398
# Epoch [3/10], Batch [700/2032], Loss: 0.0435
# Epoch [3/10], Batch [800/2032], Loss: 0.1110
# Epoch [3/10], Batch [900/2032], Loss: 0.0402
# Epoch [3/10], Batch [1000/2032], Loss: 0.0474
# Epoch [3/10], Batch [1100/2032], Loss: 43.0021
# Epoch [3/10], Batch [1200/2032], Loss: 12.5160
# Epoch [3/10], Batch [1300/2032], Loss: 0.2478
# Epoch [3/10], Batch [1400/2032], Loss: 0.3713
# Epoch [3/10], Batch [1500/2032], Loss: 0.0391
# Epoch [3/10], Batch [1600/2032], Loss: 0.0393
# Epoch [3/10], Batch [1700/2032], Loss: 0.0534
# Epoch [3/10], Batch [1800/2032], Loss: 0.0418
# Epoch [3/10], Batch [1900/2032], Loss: 0.0558
# Epoch [3/10], Batch [2000/2032], Loss: 0.0447
# Epoch [3/10], Train Loss: 196.1122, Validation Loss: 0.0474
# Epoch [4/10], Batch [100/2032], Loss: 0.0434
# Epoch [4/10], Batch [200/2032], Loss: 0.0432
# Epoch [4/10], Batch [300/2032], Loss: 0.0366
# Epoch [4/10], Batch [400/2032], Loss: 0.0581
# Epoch [4/10], Batch [500/2032], Loss: 0.0409
# Epoch [4/10], Batch [600/2032], Loss: 0.1751
# Epoch [4/10], Batch [700/2032], Loss: 0.0427
# Epoch [4/10], Batch [800/2032], Loss: 0.6253
# Epoch [4/10], Batch [900/2032], Loss: 0.0472
# Epoch [4/10], Batch [1000/2032], Loss: 0.0381
# Epoch [4/10], Batch [1100/2032], Loss: 0.0478
# Epoch [4/10], Batch [1200/2032], Loss: 0.3269
# Epoch [4/10], Batch [1300/2032], Loss: 0.0446
# Epoch [4/10], Batch [1400/2032], Loss: 0.0559
# Epoch [4/10], Batch [1500/2032], Loss: 0.0444
# Epoch [4/10], Batch [1600/2032], Loss: 0.0895
# Epoch [4/10], Batch [1700/2032], Loss: 0.0463
# Epoch [4/10], Batch [1800/2032], Loss: 0.0428
# Epoch [4/10], Batch [1900/2032], Loss: 0.0431
# Epoch [4/10], Batch [2000/2032], Loss: 0.0476
# Epoch [4/10], Train Loss: 1.1685, Validation Loss: 0.0464
# Epoch [5/10], Batch [100/2032], Loss: 0.0414
# Epoch [5/10], Batch [200/2032], Loss: 0.0401
# Epoch [5/10], Batch [300/2032], Loss: 0.0442
# Epoch [5/10], Batch [400/2032], Loss: 0.0521
# Epoch [5/10], Batch [500/2032], Loss: 0.0535
# Epoch [5/10], Batch [600/2032], Loss: 0.0493
# Epoch [5/10], Batch [700/2032], Loss: 0.0585
# Epoch [5/10], Batch [800/2032], Loss: 0.0451
# Epoch [5/10], Batch [900/2032], Loss: 0.0481
# Epoch [5/10], Batch [1000/2032], Loss: 0.0685
# Epoch [5/10], Batch [1100/2032], Loss: 0.0414
# Epoch [5/10], Batch [1200/2032], Loss: 0.0650
# Epoch [5/10], Batch [1300/2032], Loss: 0.0328
# Epoch [5/10], Batch [1400/2032], Loss: 0.0505
# Epoch [5/10], Batch [1500/2032], Loss: 0.0480
# Epoch [5/10], Batch [1600/2032], Loss: 0.0441
# Epoch [5/10], Batch [1700/2032], Loss: 0.0332
# Epoch [5/10], Batch [1800/2032], Loss: 0.0519
# Epoch [5/10], Batch [1900/2032], Loss: 0.0504
# Epoch [5/10], Batch [2000/2032], Loss: 0.0627
# Epoch [5/10], Train Loss: 0.1223, Validation Loss: 0.0464
# Epoch [6/10], Batch [100/2032], Loss: 0.0519
# Epoch [6/10], Batch [200/2032], Loss: 0.0428
# Epoch [6/10], Batch [300/2032], Loss: 0.0453
# Epoch [6/10], Batch [400/2032], Loss: 0.0642
# Epoch [6/10], Batch [500/2032], Loss: 0.0470
# Epoch [6/10], Batch [600/2032], Loss: 0.0468
# Epoch [6/10], Batch [700/2032], Loss: 0.0355
# Epoch [6/10], Batch [800/2032], Loss: 0.0425
# Epoch [6/10], Batch [900/2032], Loss: 0.0475
# Epoch [6/10], Batch [1000/2032], Loss: 0.0449
# Epoch [6/10], Batch [1100/2032], Loss: 0.0408
# Epoch [6/10], Batch [1200/2032], Loss: 0.0418
# Epoch [6/10], Batch [1300/2032], Loss: 0.0457
# Epoch [6/10], Batch [1400/2032], Loss: 0.0512
# Epoch [6/10], Batch [1500/2032], Loss: 0.0449
# Epoch [6/10], Batch [1600/2032], Loss: 0.0496
# Epoch [6/10], Batch [1700/2032], Loss: 0.0416
# Epoch [6/10], Batch [1800/2032], Loss: 0.0463
# Epoch [6/10], Batch [1900/2032], Loss: 0.0533
# Epoch [6/10], Batch [2000/2032], Loss: 0.0716
# Epoch [6/10], Train Loss: 0.1258, Validation Loss: 0.0970
# Epoch [7/10], Batch [100/2032], Loss: 0.0390
# Epoch [7/10], Batch [200/2032], Loss: 0.0464
# Epoch [7/10], Batch [300/2032], Loss: 0.0453
# Epoch [7/10], Batch [400/2032], Loss: 0.0581
# Epoch [7/10], Batch [500/2032], Loss: 0.0358
# Epoch [7/10], Batch [600/2032], Loss: 0.0420
# Epoch [7/10], Batch [700/2032], Loss: 0.0632
# Epoch [7/10], Batch [800/2032], Loss: 0.0461
# Epoch [7/10], Batch [900/2032], Loss: 0.1427
# Epoch [7/10], Batch [1000/2032], Loss: 0.0588
# Epoch [7/10], Batch [1100/2032], Loss: 0.0347
# Epoch [7/10], Batch [1200/2032], Loss: 0.1309
# Epoch [7/10], Batch [1300/2032], Loss: 0.0533
# Epoch [7/10], Batch [1400/2032], Loss: 0.0400
# Epoch [7/10], Batch [1500/2032], Loss: 0.0629
# Epoch [7/10], Batch [1600/2032], Loss: 0.0454
# Epoch [7/10], Batch [1700/2032], Loss: 0.0486
# Epoch [7/10], Batch [1800/2032], Loss: 0.0580
# Epoch [7/10], Batch [1900/2032], Loss: 0.0559
# Epoch [7/10], Batch [2000/2032], Loss: 0.0423
# Epoch [7/10], Train Loss: 0.1005, Validation Loss: 1.2465
# Epoch [8/10], Batch [100/2032], Loss: 0.0481
# Epoch [8/10], Batch [200/2032], Loss: 0.0471
# Epoch [8/10], Batch [300/2032], Loss: 0.3298
# Epoch [8/10], Batch [400/2032], Loss: 0.0509
# Epoch [8/10], Batch [500/2032], Loss: 0.0833
# Epoch [8/10], Batch [600/2032], Loss: 0.0992
# Epoch [8/10], Batch [700/2032], Loss: 0.0532
# Epoch [8/10], Batch [800/2032], Loss: 0.0320
# Epoch [8/10], Batch [900/2032], Loss: 0.0559
# Epoch [8/10], Batch [1000/2032], Loss: 0.1410
# Epoch [8/10], Batch [1100/2032], Loss: 0.0387
# Epoch [8/10], Batch [1200/2032], Loss: 0.0389
# Epoch [8/10], Batch [1300/2032], Loss: 0.0487
# Epoch [8/10], Batch [1400/2032], Loss: 0.0529
# Epoch [8/10], Batch [1500/2032], Loss: 0.0679
# Epoch [8/10], Batch [1600/2032], Loss: 0.0484
# Epoch [8/10], Batch [1700/2032], Loss: 0.0550
# Epoch [8/10], Batch [1800/2032], Loss: 0.0425
# Epoch [8/10], Batch [1900/2032], Loss: 0.0471
# Epoch [8/10], Batch [2000/2032], Loss: 0.0453
# Epoch [8/10], Train Loss: 0.1195, Validation Loss: 0.0567
# Epoch [9/10], Batch [100/2032], Loss: 0.0725
# Epoch [9/10], Batch [200/2032], Loss: 0.0716
# Epoch [9/10], Batch [300/2032], Loss: 0.0479
# Epoch [9/10], Batch [400/2032], Loss: 0.0382
# Epoch [9/10], Batch [500/2032], Loss: 0.0362
# Epoch [9/10], Batch [600/2032], Loss: 0.0516
# Epoch [9/10], Batch [700/2032], Loss: 0.0385
# Epoch [9/10], Batch [800/2032], Loss: 0.0421
# Epoch [9/10], Batch [900/2032], Loss: 0.0370
# Epoch [9/10], Batch [1000/2032], Loss: 0.0632
# Epoch [9/10], Batch [1100/2032], Loss: 0.0408
# Epoch [9/10], Batch [1200/2032], Loss: 0.0502
# Epoch [9/10], Batch [1300/2032], Loss: 0.0561
# Epoch [9/10], Batch [1400/2032], Loss: 0.0384
# Epoch [9/10], Batch [1500/2032], Loss: 0.0365
# Epoch [9/10], Batch [1600/2032], Loss: 0.0410
# Epoch [9/10], Batch [1700/2032], Loss: 0.0480
# Epoch [9/10], Batch [1800/2032], Loss: 0.0428
# Epoch [9/10], Batch [1900/2032], Loss: 0.0432
# Epoch [9/10], Batch [2000/2032], Loss: 0.0647
# Epoch [9/10], Train Loss: 0.0548, Validation Loss: 0.0466
# Epoch [10/10], Batch [100/2032], Loss: 0.0433
# Epoch [10/10], Batch [200/2032], Loss: 0.0424
# Epoch [10/10], Batch [300/2032], Loss: 0.0475
# Epoch [10/10], Batch [400/2032], Loss: 0.0469
# Epoch [10/10], Batch [500/2032], Loss: 0.0528
# Epoch [10/10], Batch [600/2032], Loss: 0.0477
# Epoch [10/10], Batch [700/2032], Loss: 0.0612
# Epoch [10/10], Batch [800/2032], Loss: 0.0454
# Epoch [10/10], Batch [900/2032], Loss: 0.0664
# Epoch [10/10], Batch [1000/2032], Loss: 0.0334
# Epoch [10/10], Batch [1100/2032], Loss: 0.0447
# Epoch [10/10], Batch [1200/2032], Loss: 0.0398
# Epoch [10/10], Batch [1300/2032], Loss: 0.0732
# Epoch [10/10], Batch [1400/2032], Loss: 0.0443
# Epoch [10/10], Batch [1500/2032], Loss: 0.0546
# Epoch [10/10], Batch [1600/2032], Loss: 0.0516
# Epoch [10/10], Batch [1700/2032], Loss: 0.0437
# Epoch [10/10], Batch [1800/2032], Loss: 0.0543
# Epoch [10/10], Batch [1900/2032], Loss: 0.0544
# Epoch [10/10], Batch [2000/2032], Loss: 0.0356
# Epoch [10/10], Train Loss: 0.0495, Validation Loss: 0.0462
# Fold 1 Validation Loss: 0.0462
# Processing fold 2/3 with hyperparameters: {'learning_rate': 0.01, 'kl_weight': 0.5, 'latent_dim': 256, 'batch_size': 32}
# Epoch [1/10], Batch [100/2032], Loss: 0.0642
# Epoch [1/10], Batch [200/2032], Loss: 0.0804
# Epoch [1/10], Batch [300/2032], Loss: 0.4518
# Epoch [1/10], Batch [400/2032], Loss: 0.1324
# Epoch [1/10], Batch [500/2032], Loss: 0.0551
# Epoch [1/10], Batch [600/2032], Loss: 0.0529
# Epoch [1/10], Batch [700/2032], Loss: 0.0614
# Epoch [1/10], Batch [800/2032], Loss: 0.0889
# Epoch [1/10], Batch [900/2032], Loss: 0.0576
# Epoch [1/10], Batch [1000/2032], Loss: 0.1442
# Epoch [1/10], Batch [1100/2032], Loss: 0.0432
# Epoch [1/10], Batch [1200/2032], Loss: 0.0406
# Epoch [1/10], Batch [1300/2032], Loss: 0.0449
# Epoch [1/10], Batch [1400/2032], Loss: 0.0443
# Epoch [1/10], Batch [1500/2032], Loss: 0.0558
# Epoch [1/10], Batch [1600/2032], Loss: 0.0483
# Epoch [1/10], Batch [1700/2032], Loss: 0.0496
# Epoch [1/10], Batch [1800/2032], Loss: 0.0430
# Epoch [1/10], Batch [1900/2032], Loss: 0.0529
# Epoch [1/10], Batch [2000/2032], Loss: 0.0541
# Epoch [1/10], Train Loss: 2.7076, Validation Loss: 0.0512
# Epoch [2/10], Batch [100/2032], Loss: 0.0474
# Epoch [2/10], Batch [200/2032], Loss: 0.0528
# Epoch [2/10], Batch [300/2032], Loss: 0.0500
# Epoch [2/10], Batch [400/2032], Loss: 5.3476
# Epoch [2/10], Batch [500/2032], Loss: 0.0434
# Epoch [2/10], Batch [600/2032], Loss: 0.0814
# Epoch [2/10], Batch [700/2032], Loss: 0.1409
# Epoch [2/10], Batch [800/2032], Loss: 0.0728
# Epoch [2/10], Batch [900/2032], Loss: 0.0655
# Epoch [2/10], Batch [1000/2032], Loss: 0.0815
# Epoch [2/10], Batch [1100/2032], Loss: 0.0605
# Epoch [2/10], Batch [1200/2032], Loss: 0.0495
# Epoch [2/10], Batch [1300/2032], Loss: 0.0393
# Epoch [2/10], Batch [1400/2032], Loss: 0.0448
# Epoch [2/10], Batch [1500/2032], Loss: 0.0601
# Epoch [2/10], Batch [1600/2032], Loss: 0.0530
# Epoch [2/10], Batch [1700/2032], Loss: 0.0583
# Epoch [2/10], Batch [1800/2032], Loss: 0.0493
# Epoch [2/10], Batch [1900/2032], Loss: 0.0615
# Epoch [2/10], Batch [2000/2032], Loss: 0.0531
# Epoch [2/10], Train Loss: 1.3476, Validation Loss: 0.0524
# Epoch [3/10], Batch [100/2032], Loss: 0.2148
# Epoch [3/10], Batch [200/2032], Loss: 0.0485
# Epoch [3/10], Batch [300/2032], Loss: 0.0483
# Epoch [3/10], Batch [400/2032], Loss: 0.0751
# Epoch [3/10], Batch [500/2032], Loss: 0.0698
# Epoch [3/10], Batch [600/2032], Loss: 0.0378
# Epoch [3/10], Batch [700/2032], Loss: 0.0407
# Epoch [3/10], Batch [800/2032], Loss: 0.0455
# Epoch [3/10], Batch [900/2032], Loss: 0.0387
# Epoch [3/10], Batch [1000/2032], Loss: 0.7769
# Epoch [3/10], Batch [1100/2032], Loss: 0.1140
# Epoch [3/10], Batch [1200/2032], Loss: 0.0354
# Epoch [3/10], Batch [1300/2032], Loss: 0.0503
# Epoch [3/10], Batch [1400/2032], Loss: 0.0634
# Epoch [3/10], Batch [1500/2032], Loss: 0.0431
# Epoch [3/10], Batch [1600/2032], Loss: 0.0505
# Epoch [3/10], Batch [1700/2032], Loss: 0.0528
# Epoch [3/10], Batch [1800/2032], Loss: 9.4946
# Epoch [3/10], Batch [1900/2032], Loss: 0.0421
# Epoch [3/10], Batch [2000/2032], Loss: 0.0566
# Epoch [3/10], Train Loss: 5.2448, Validation Loss: 0.2900
# Epoch [4/10], Batch [100/2032], Loss: 0.0440
# Epoch [4/10], Batch [200/2032], Loss: 0.0443
# Epoch [4/10], Batch [300/2032], Loss: 0.0366
# Epoch [4/10], Batch [400/2032], Loss: 0.0443
# Epoch [4/10], Batch [500/2032], Loss: 0.0533
# Epoch [4/10], Batch [600/2032], Loss: 0.0541
# Epoch [4/10], Batch [700/2032], Loss: 0.0498
# Epoch [4/10], Batch [800/2032], Loss: 0.0433
# Epoch [4/10], Batch [900/2032], Loss: 0.0517
# Epoch [4/10], Batch [1000/2032], Loss: 0.0494
# Epoch [4/10], Batch [1100/2032], Loss: 0.0419
# Epoch [4/10], Batch [1200/2032], Loss: 0.0487
# Epoch [4/10], Batch [1300/2032], Loss: 0.0425
# Epoch [4/10], Batch [1400/2032], Loss: 0.0429
# Epoch [4/10], Batch [1500/2032], Loss: 0.0594
# Epoch [4/10], Batch [1600/2032], Loss: 0.0403
# Epoch [4/10], Batch [1700/2032], Loss: 0.0558
# Epoch [4/10], Batch [1800/2032], Loss: 0.0373
# Epoch [4/10], Batch [1900/2032], Loss: 0.0474
# Epoch [4/10], Batch [2000/2032], Loss: 0.0431
# Epoch [4/10], Train Loss: 0.0626, Validation Loss: 0.0469
# Epoch [5/10], Batch [100/2032], Loss: 0.0599
# Epoch [5/10], Batch [200/2032], Loss: 0.0375
# Epoch [5/10], Batch [300/2032], Loss: 0.0438
# Epoch [5/10], Batch [400/2032], Loss: 0.0611
# Epoch [5/10], Batch [500/2032], Loss: 0.0458
# Epoch [5/10], Batch [600/2032], Loss: 0.0440
# Epoch [5/10], Batch [700/2032], Loss: 0.0406
# Epoch [5/10], Batch [800/2032], Loss: 0.0409
# Epoch [5/10], Batch [900/2032], Loss: 0.0494
# Epoch [5/10], Batch [1000/2032], Loss: 0.0439
# Epoch [5/10], Batch [1100/2032], Loss: 0.0458
# Epoch [5/10], Batch [1200/2032], Loss: 0.0457
# Epoch [5/10], Batch [1300/2032], Loss: 0.0449
# Epoch [5/10], Batch [1400/2032], Loss: 0.0527
# Epoch [5/10], Batch [1500/2032], Loss: 0.0393
# Epoch [5/10], Batch [1600/2032], Loss: 0.0522
# Epoch [5/10], Batch [1700/2032], Loss: 0.0359
# Epoch [5/10], Batch [1800/2032], Loss: 0.0687
# Epoch [5/10], Batch [1900/2032], Loss: 0.0574
# Epoch [5/10], Batch [2000/2032], Loss: 0.0406
# Epoch [5/10], Train Loss: 0.0468, Validation Loss: 0.0467
# Epoch [6/10], Batch [100/2032], Loss: 0.0547
# Epoch [6/10], Batch [200/2032], Loss: 0.0444
# Epoch [6/10], Batch [300/2032], Loss: 0.0449
# Epoch [6/10], Batch [400/2032], Loss: 0.0454
# Epoch [6/10], Batch [500/2032], Loss: 0.0446
# Epoch [6/10], Batch [600/2032], Loss: 0.0398
# Epoch [6/10], Batch [700/2032], Loss: 0.0680
# Epoch [6/10], Batch [800/2032], Loss: 0.0528
# Epoch [6/10], Batch [900/2032], Loss: 0.0386
# Epoch [6/10], Batch [1000/2032], Loss: 0.0427
# Epoch [6/10], Batch [1100/2032], Loss: 0.0327
# Epoch [6/10], Batch [1200/2032], Loss: 0.0439
# Epoch [6/10], Batch [1300/2032], Loss: 0.0535
# Epoch [6/10], Batch [1400/2032], Loss: 0.0467
# Epoch [6/10], Batch [1500/2032], Loss: 0.0453
# Epoch [6/10], Batch [1600/2032], Loss: 0.0446
# Epoch [6/10], Batch [1700/2032], Loss: 0.0361
# Epoch [6/10], Batch [1800/2032], Loss: 0.0603
# Epoch [6/10], Batch [1900/2032], Loss: 0.0398
# Epoch [6/10], Batch [2000/2032], Loss: 0.0500
# Epoch [6/10], Train Loss: 0.0470, Validation Loss: 0.0469
# Epoch [7/10], Batch [100/2032], Loss: 0.0629
# Epoch [7/10], Batch [200/2032], Loss: 0.0379
# Epoch [7/10], Batch [300/2032], Loss: 0.0500
# Epoch [7/10], Batch [400/2032], Loss: 0.0469
# Epoch [7/10], Batch [500/2032], Loss: 0.0451
# Epoch [7/10], Batch [600/2032], Loss: 0.0365
# Epoch [7/10], Batch [700/2032], Loss: 0.0392
# Epoch [7/10], Batch [800/2032], Loss: 0.0448
# Epoch [7/10], Batch [900/2032], Loss: 0.0430
# Epoch [7/10], Batch [1000/2032], Loss: 0.0459
# Epoch [7/10], Batch [1100/2032], Loss: 0.0419
# Epoch [7/10], Batch [1200/2032], Loss: 0.0317
# Epoch [7/10], Batch [1300/2032], Loss: 0.0375
# Epoch [7/10], Batch [1400/2032], Loss: 0.0630
# Epoch [7/10], Batch [1500/2032], Loss: 0.0295
# Epoch [7/10], Batch [1600/2032], Loss: 0.0453
# Epoch [7/10], Batch [1700/2032], Loss: 0.0477
# Epoch [7/10], Batch [1800/2032], Loss: 0.0541
# Epoch [7/10], Batch [1900/2032], Loss: 0.0529
# Epoch [7/10], Batch [2000/2032], Loss: 0.0557
# Epoch [7/10], Train Loss: 0.0471, Validation Loss: 0.0469
# Epoch [8/10], Batch [100/2032], Loss: 0.0622
# Epoch [8/10], Batch [200/2032], Loss: 0.0460
# Epoch [8/10], Batch [300/2032], Loss: 0.0410
# Epoch [8/10], Batch [400/2032], Loss: 0.0456
# Epoch [8/10], Batch [500/2032], Loss: 0.0458
# Epoch [8/10], Batch [600/2032], Loss: 0.0432
# Epoch [8/10], Batch [700/2032], Loss: 0.0403
# Epoch [8/10], Batch [800/2032], Loss: 0.0442
# Epoch [8/10], Batch [900/2032], Loss: 0.0358
# Epoch [8/10], Batch [1000/2032], Loss: 0.0424
# Epoch [8/10], Batch [1100/2032], Loss: 0.0580
# Epoch [8/10], Batch [1200/2032], Loss: 0.0417
# Epoch [8/10], Batch [1300/2032], Loss: 0.0420
# Epoch [8/10], Batch [1400/2032], Loss: 0.0492
# Epoch [8/10], Batch [1500/2032], Loss: 0.0475
# Epoch [8/10], Batch [1600/2032], Loss: 0.0558
# Epoch [8/10], Batch [1700/2032], Loss: 0.0412
# Epoch [8/10], Batch [1800/2032], Loss: 0.0450
# Epoch [8/10], Batch [1900/2032], Loss: 0.0457
# Epoch [8/10], Batch [2000/2032], Loss: 0.0651
# Epoch [8/10], Train Loss: 0.0474, Validation Loss: 0.0473
# Epoch [9/10], Batch [100/2032], Loss: 0.0380
# Epoch [9/10], Batch [200/2032], Loss: 0.0456
# Epoch [9/10], Batch [300/2032], Loss: 0.0511
# Epoch [9/10], Batch [400/2032], Loss: 0.0979
# Epoch [9/10], Batch [500/2032], Loss: 0.0533
# Epoch [9/10], Batch [600/2032], Loss: 0.0354
# Epoch [9/10], Batch [700/2032], Loss: 0.0514
# Epoch [9/10], Batch [800/2032], Loss: 0.0436
# Epoch [9/10], Batch [900/2032], Loss: 0.0400
# Epoch [9/10], Batch [1000/2032], Loss: 0.0374
# Epoch [9/10], Batch [1100/2032], Loss: 0.0401
# Epoch [9/10], Batch [1200/2032], Loss: 0.0500
# Epoch [9/10], Batch [1300/2032], Loss: 0.0653
# Epoch [9/10], Batch [1400/2032], Loss: 0.0457
# Epoch [9/10], Batch [1500/2032], Loss: 0.0496
# Epoch [9/10], Batch [1600/2032], Loss: 0.0386
# Epoch [9/10], Batch [1700/2032], Loss: 0.0398
# Epoch [9/10], Batch [1800/2032], Loss: 0.0553
# Epoch [9/10], Batch [1900/2032], Loss: 0.0412
# Epoch [9/10], Batch [2000/2032], Loss: 0.0522
# Epoch [9/10], Train Loss: 0.0471, Validation Loss: 0.0467
# Epoch [10/10], Batch [100/2032], Loss: 0.0435
# Epoch [10/10], Batch [200/2032], Loss: 0.0421
# Epoch [10/10], Batch [300/2032], Loss: 0.0440
# Epoch [10/10], Batch [400/2032], Loss: 0.0649
# Epoch [10/10], Batch [500/2032], Loss: 0.0535
# Epoch [10/10], Batch [600/2032], Loss: 0.0502
# Epoch [10/10], Batch [700/2032], Loss: 0.0516
# Epoch [10/10], Batch [800/2032], Loss: 0.0561
# Epoch [10/10], Batch [900/2032], Loss: 0.0472
# Epoch [10/10], Batch [1000/2032], Loss: 0.0434
# Epoch [10/10], Batch [1100/2032], Loss: 0.0511
# Epoch [10/10], Batch [1200/2032], Loss: 0.0584
# Epoch [10/10], Batch [1300/2032], Loss: 0.0527
# Epoch [10/10], Batch [1400/2032], Loss: 0.0535
# Epoch [10/10], Batch [1500/2032], Loss: 0.0463
# Epoch [10/10], Batch [1600/2032], Loss: 0.0372
# Epoch [10/10], Batch [1700/2032], Loss: 0.0359
# Epoch [10/10], Batch [1800/2032], Loss: 0.0402
# Epoch [10/10], Batch [1900/2032], Loss: 0.0463
# Epoch [10/10], Batch [2000/2032], Loss: 0.0404
# Epoch [10/10], Train Loss: 0.0472, Validation Loss: 0.0470
# Fold 2 Validation Loss: 0.0470
# Processing fold 3/3 with hyperparameters: {'learning_rate': 0.01, 'kl_weight': 0.5, 'latent_dim': 256, 'batch_size': 32}
# Epoch [1/10], Batch [100/2032], Loss: 0.1072
# Epoch [1/10], Batch [200/2032], Loss: 0.0881
# Epoch [1/10], Batch [300/2032], Loss: 0.0773
# Epoch [1/10], Batch [400/2032], Loss: 0.0550
# Epoch [1/10], Batch [500/2032], Loss: 0.0662
# Epoch [1/10], Batch [600/2032], Loss: 0.0672
# Epoch [1/10], Batch [700/2032], Loss: 0.0624
# Epoch [1/10], Batch [800/2032], Loss: 0.0544
# Epoch [1/10], Batch [900/2032], Loss: 0.0731
# Epoch [1/10], Batch [1000/2032], Loss: 0.0591
# Epoch [1/10], Batch [1100/2032], Loss: 0.0462
# Epoch [1/10], Batch [1200/2032], Loss: 0.0583
# Epoch [1/10], Batch [1300/2032], Loss: 0.0575
# Epoch [1/10], Batch [1400/2032], Loss: 0.0501
# Epoch [1/10], Batch [1500/2032], Loss: 0.0521
# Epoch [1/10], Batch [1600/2032], Loss: 0.0474
# Epoch [1/10], Batch [1700/2032], Loss: 0.0480
# Epoch [1/10], Batch [1800/2032], Loss: 0.0406
# Epoch [1/10], Batch [1900/2032], Loss: 0.0606
# Epoch [1/10], Batch [2000/2032], Loss: 0.0493
# Epoch [1/10], Train Loss: 12.2451, Validation Loss: 0.0567
# Epoch [2/10], Batch [100/2032], Loss: 1.3975
# Epoch [2/10], Batch [200/2032], Loss: 0.0408
# Epoch [2/10], Batch [300/2032], Loss: 0.0475
# Epoch [2/10], Batch [400/2032], Loss: 0.0749
# Epoch [2/10], Batch [500/2032], Loss: 0.0470
# Epoch [2/10], Batch [600/2032], Loss: 0.0411
# Epoch [2/10], Batch [700/2032], Loss: 0.0525
# Epoch [2/10], Batch [800/2032], Loss: 0.0757
# Epoch [2/10], Batch [900/2032], Loss: 0.4388
# Epoch [2/10], Batch [1000/2032], Loss: 0.0634
# Epoch [2/10], Batch [1100/2032], Loss: 0.0505
# Epoch [2/10], Batch [1200/2032], Loss: 0.0486
# Epoch [2/10], Batch [1300/2032], Loss: 0.0462
# Epoch [2/10], Batch [1400/2032], Loss: 0.0430
# Epoch [2/10], Batch [1500/2032], Loss: 0.0443
# Epoch [2/10], Batch [1600/2032], Loss: 0.0519
# Epoch [2/10], Batch [1700/2032], Loss: 0.0490
# Epoch [2/10], Batch [1800/2032], Loss: 0.0504
# Epoch [2/10], Batch [1900/2032], Loss: 0.0449
# Epoch [2/10], Batch [2000/2032], Loss: 0.0417
# Epoch [2/10], Train Loss: 0.1948, Validation Loss: 0.0667
# Epoch [3/10], Batch [100/2032], Loss: 0.0532
# Epoch [3/10], Batch [200/2032], Loss: 0.0559
# Epoch [3/10], Batch [300/2032], Loss: 0.0553
# Epoch [3/10], Batch [400/2032], Loss: 0.0492
# Epoch [3/10], Batch [500/2032], Loss: 0.0455
# Epoch [3/10], Batch [600/2032], Loss: 0.0475
# Epoch [3/10], Batch [700/2032], Loss: 19.7360
# Epoch [3/10], Batch [800/2032], Loss: 0.0780
# Epoch [3/10], Batch [900/2032], Loss: 0.0485
# Epoch [3/10], Batch [1000/2032], Loss: 0.0493
# Epoch [3/10], Batch [1100/2032], Loss: 0.0388
# Epoch [3/10], Batch [1200/2032], Loss: 0.0549
# Epoch [3/10], Batch [1300/2032], Loss: 0.0524
# Epoch [3/10], Batch [1400/2032], Loss: 0.0527
# Epoch [3/10], Batch [1500/2032], Loss: 0.0445
# Epoch [3/10], Batch [1600/2032], Loss: 0.0685
# Epoch [3/10], Batch [1700/2032], Loss: 0.0385
# Epoch [3/10], Batch [1800/2032], Loss: 0.0765
# Epoch [3/10], Batch [1900/2032], Loss: 0.0554
# Epoch [3/10], Batch [2000/2032], Loss: 0.0463
# Epoch [3/10], Train Loss: 2.3231, Validation Loss: 0.0477
# Epoch [4/10], Batch [100/2032], Loss: 0.0346
# Epoch [4/10], Batch [200/2032], Loss: 0.0436
# Epoch [4/10], Batch [300/2032], Loss: 0.0457
# Epoch [4/10], Batch [400/2032], Loss: 0.0437
# Epoch [4/10], Batch [500/2032], Loss: 0.0445
# Epoch [4/10], Batch [600/2032], Loss: 0.0425
# Epoch [4/10], Batch [700/2032], Loss: 0.5017
# Epoch [4/10], Batch [800/2032], Loss: 0.0546
# Epoch [4/10], Batch [900/2032], Loss: 0.0420
# Epoch [4/10], Batch [1000/2032], Loss: 0.0739
# Epoch [4/10], Batch [1100/2032], Loss: 0.0478
# Epoch [4/10], Batch [1200/2032], Loss: 0.0530
# Epoch [4/10], Batch [1300/2032], Loss: 0.0350
# Epoch [4/10], Batch [1400/2032], Loss: 0.0437
# Epoch [4/10], Batch [1500/2032], Loss: 0.0374
# Epoch [4/10], Batch [1600/2032], Loss: 0.0446
# Epoch [4/10], Batch [1700/2032], Loss: 0.0394
# Epoch [4/10], Batch [1800/2032], Loss: 0.0496
# Epoch [4/10], Batch [1900/2032], Loss: 0.0624
# Epoch [4/10], Batch [2000/2032], Loss: 0.0462
# Epoch [4/10], Train Loss: 0.8588, Validation Loss: 0.0468
# Epoch [5/10], Batch [100/2032], Loss: 0.0537
# ...
# Epoch [8/10], Batch [400/508], Loss: 0.0548
# Epoch [8/10], Batch [500/508], Loss: 0.0455
# Epoch [8/10], Train Loss: 0.0482, Validation Loss: 0.0479
# Epoch [9/10], Batch [100/508], Loss: 0.0429
# Epoch [9/10], Batch [200/508], Loss: 0.0417
# Epoch [9/10], Batch [300/508], Loss: 0.0508
# Epoch [9/10], Batch [400/508], Loss: 0.0468
# Epoch [9/10], Batch [500/508], Loss: 0.0483
# Epoch [9/10], Train Loss: 0.0478, Validation Loss: 0.0476
# Epoch [10/10], Batch [100/508], Loss: 0.0435
# Epoch [10/10], Batch [200/508], Loss: 0.0590
# Epoch [10/10], Batch [300/508], Loss: 0.0444
# Epoch [10/10], Batch [400/508], Loss: 0.0424
# Epoch [10/10], Batch [500/508], Loss: 0.0597
# Epoch [10/10], Train Loss: 0.0475, Validation Loss: 0.0473
# Fold 1 Validation Loss: 0.0473
# Processing fold 2/3 with hyperparameters: {'learning_rate': 0.0001, 'kl_weight': 1.0, 'latent_dim': 128, 'batch_size': 128}
# Epoch [1/10], Batch [100/508], Loss: 0.5542
# Epoch [1/10], Batch [200/508], Loss: 0.2854
# Epoch [1/10], Batch [300/508], Loss: 0.1886
# Epoch [1/10], Batch [400/508], Loss: 0.1604
# Epoch [1/10], Batch [500/508], Loss: 0.1215
# Epoch [1/10], Train Loss: 0.9682, Validation Loss: 0.1300
# Epoch [2/10], Batch [100/508], Loss: 0.1061
# Epoch [2/10], Batch [200/508], Loss: 0.0987
# Epoch [2/10], Batch [300/508], Loss: 0.0752
# Epoch [2/10], Batch [400/508], Loss: 0.0773
# Epoch [2/10], Batch [500/508], Loss: 0.0796
# Epoch [2/10], Train Loss: 0.0918, Validation Loss: 0.0732
# Epoch [3/10], Batch [100/508], Loss: 0.0673
# Epoch [3/10], Batch [200/508], Loss: 0.0586
# Epoch [3/10], Batch [300/508], Loss: 0.0670
# Epoch [3/10], Batch [400/508], Loss: 0.0616
# Epoch [3/10], Batch [500/508], Loss: 0.0565
# Epoch [3/10], Train Loss: 0.0616, Validation Loss: 0.0578
# Epoch [4/10], Batch [100/508], Loss: 0.0535
# Epoch [4/10], Batch [200/508], Loss: 0.0609
# Epoch [4/10], Batch [300/508], Loss: 0.0567
# Epoch [4/10], Batch [400/508], Loss: 0.0499
# Epoch [4/10], Batch [500/508], Loss: 0.0591
# Epoch [4/10], Train Loss: 0.0539, Validation Loss: 0.0532
# Epoch [5/10], Batch [100/508], Loss: 0.0460
# Epoch [5/10], Batch [200/508], Loss: 0.0498
# Epoch [5/10], Batch [300/508], Loss: 0.0481
# Epoch [5/10], Batch [400/508], Loss: 0.0461
# Epoch [5/10], Batch [500/508], Loss: 0.0537
# Epoch [5/10], Train Loss: 0.0508, Validation Loss: 0.0511
# Epoch [6/10], Batch [100/508], Loss: 0.0442
# Epoch [6/10], Batch [200/508], Loss: 0.0449
# Epoch [6/10], Batch [300/508], Loss: 0.0478
# Epoch [6/10], Batch [400/508], Loss: 0.0487
# Epoch [6/10], Batch [500/508], Loss: 0.0466
# Epoch [6/10], Train Loss: 0.0496, Validation Loss: 0.0499
# Epoch [7/10], Batch [100/508], Loss: 0.0544
# Epoch [7/10], Batch [200/508], Loss: 0.0493
# Epoch [7/10], Batch [300/508], Loss: 0.0533
# Epoch [7/10], Batch [400/508], Loss: 0.0430
# Epoch [7/10], Batch [500/508], Loss: 0.0444
# Epoch [7/10], Train Loss: 0.0487, Validation Loss: 0.0490
# Epoch [8/10], Batch [100/508], Loss: 0.0479
# Epoch [8/10], Batch [200/508], Loss: 0.0468
# Epoch [8/10], Batch [300/508], Loss: 0.0392
# Epoch [8/10], Batch [400/508], Loss: 0.0477
# Epoch [8/10], Batch [500/508], Loss: 0.0456
# Epoch [8/10], Train Loss: 0.0482, Validation Loss: 0.0486
# Epoch [9/10], Batch [100/508], Loss: 0.0531
# Epoch [9/10], Batch [200/508], Loss: 0.0501
# Epoch [9/10], Batch [300/508], Loss: 0.0492
# Epoch [9/10], Batch [400/508], Loss: 0.0486
# Epoch [9/10], Batch [500/508], Loss: 0.0517
# Epoch [9/10], Train Loss: 0.0476, Validation Loss: 0.0480
# Epoch [10/10], Batch [100/508], Loss: 0.0464
# Epoch [10/10], Batch [200/508], Loss: 0.0515
# Epoch [10/10], Batch [300/508], Loss: 0.0451
# Epoch [10/10], Batch [400/508], Loss: 0.0439
# Epoch [10/10], Batch [500/508], Loss: 0.0475
# Epoch [10/10], Train Loss: 0.0474, Validation Loss: 0.0476
# Fold 2 Validation Loss: 0.0476
# Processing fold 3/3 with hyperparameters: {'learning_rate': 0.0001, 'kl_weight': 1.0, 'latent_dim': 128, 'batch_size': 128}
# Epoch [1/10], Batch [100/508], Loss: 0.7274
# Epoch [1/10], Batch [200/508], Loss: 0.3163
# Epoch [1/10], Batch [300/508], Loss: 0.2257
# Epoch [1/10], Batch [400/508], Loss: 0.1974
# Epoch [1/10], Batch [500/508], Loss: 0.1455
# Epoch [1/10], Train Loss: 1.1860, Validation Loss: 0.1477
# Epoch [2/10], Batch [100/508], Loss: 0.1100
# Epoch [2/10], Batch [200/508], Loss: 0.1093
# Epoch [2/10], Batch [300/508], Loss: 0.1012
# Epoch [2/10], Batch [400/508], Loss: 0.0881
# Epoch [2/10], Batch [500/508], Loss: 0.0849
# Epoch [2/10], Train Loss: 0.1053, Validation Loss: 0.0889
# Epoch [3/10], Batch [100/508], Loss: 0.0731
# Epoch [3/10], Batch [200/508], Loss: 0.0669
# Epoch [3/10], Batch [300/508], Loss: 0.0650
# Epoch [3/10], Batch [400/508], Loss: 0.0588
# Epoch [3/10], Batch [500/508], Loss: 0.0541
# Epoch [3/10], Train Loss: 0.0695, Validation Loss: 0.0665
# Epoch [4/10], Batch [100/508], Loss: 0.0600
# Epoch [4/10], Batch [200/508], Loss: 0.0531
# Epoch [4/10], Batch [300/508], Loss: 0.0593
# Epoch [4/10], Batch [400/508], Loss: 0.0492
# Epoch [4/10], Batch [500/508], Loss: 0.0607
# Epoch [4/10], Train Loss: 0.0578, Validation Loss: 0.0572
# Epoch [5/10], Batch [100/508], Loss: 0.0538
# Epoch [5/10], Batch [200/508], Loss: 0.0779
# Epoch [5/10], Batch [300/508], Loss: 0.0501
# Epoch [5/10], Batch [400/508], Loss: 0.0529
# Epoch [5/10], Batch [500/508], Loss: 0.0586
# Epoch [5/10], Train Loss: 0.0529, Validation Loss: 0.0530
# Epoch [6/10], Batch [100/508], Loss: 0.0482
# Epoch [6/10], Batch [200/508], Loss: 0.0477
# Epoch [6/10], Batch [300/508], Loss: 0.0560
# Epoch [6/10], Batch [400/508], Loss: 0.0477
# Epoch [6/10], Batch [500/508], Loss: 0.0436
# Epoch [6/10], Train Loss: 0.0506, Validation Loss: 0.0505
# Epoch [7/10], Batch [100/508], Loss: 0.0485
# Epoch [7/10], Batch [200/508], Loss: 0.0437
# Epoch [7/10], Batch [300/508], Loss: 0.0471
# Epoch [7/10], Batch [400/508], Loss: 0.0462
# Epoch [7/10], Batch [500/508], Loss: 0.0485
# Epoch [7/10], Train Loss: 0.0491, Validation Loss: 0.0492
# Epoch [8/10], Batch [100/508], Loss: 0.0411
# Epoch [8/10], Batch [200/508], Loss: 0.0486
# Epoch [8/10], Batch [300/508], Loss: 0.0519
# Epoch [8/10], Batch [400/508], Loss: 0.0461
# Epoch [8/10], Batch [500/508], Loss: 0.0477
# Epoch [8/10], Train Loss: 0.0483, Validation Loss: 0.0485
# Epoch [9/10], Batch [100/508], Loss: 0.0521
# Epoch [9/10], Batch [200/508], Loss: 0.0437
# Epoch [9/10], Batch [300/508], Loss: 0.0502
# Epoch [9/10], Batch [400/508], Loss: 0.0471
# Epoch [9/10], Batch [500/508], Loss: 0.0492
# Epoch [9/10], Train Loss: 0.0477, Validation Loss: 0.0480
# Epoch [10/10], Batch [100/508], Loss: 0.0358
# Epoch [10/10], Batch [200/508], Loss: 0.0531
# Epoch [10/10], Batch [300/508], Loss: 0.0483
# Epoch [10/10], Batch [400/508], Loss: 0.0791
# Epoch [10/10], Batch [500/508], Loss: 0.0457
# Epoch [10/10], Train Loss: 0.0474, Validation Loss: 0.0475
# Fold 3 Validation Loss: 0.0475
# Current best validation loss: 0.0460 with hyperparameters: {'learning_rate': 0.001, 'kl_weight': 1.0, 'latent_dim': 64, 'batch_size': 128}
# Evaluating hyperparameters: {'learning_rate': 0.0001, 'kl_weight': 1.0, 'latent_dim': 64, 'batch_size': 128}
# Processing fold 1/3 with hyperparameters: {'learning_rate': 0.0001, 'kl_weight': 1.0, 'latent_dim': 64, 'batch_size': 128}
# Epoch [1/10], Batch [100/508], Loss: 0.3287
# Epoch [1/10], Batch [200/508], Loss: 0.1761
# Epoch [1/10], Batch [300/508], Loss: 0.1377
# Epoch [1/10], Batch [400/508], Loss: 0.1209
# Epoch [1/10], Batch [500/508], Loss: 0.0933
# Epoch [1/10], Train Loss: 0.4929, Validation Loss: 0.0993
# Epoch [2/10], Batch [100/508], Loss: 0.0833
# Epoch [2/10], Batch [200/508], Loss: 0.1034
# Epoch [2/10], Batch [300/508], Loss: 0.0759
# Epoch [2/10], Batch [400/508], Loss: 0.0701
# Epoch [2/10], Batch [500/508], Loss: 0.0655
# Epoch [2/10], Train Loss: 0.0788, Validation Loss: 0.0693
# Epoch [3/10], Batch [100/508], Loss: 0.0680
# Epoch [3/10], Batch [200/508], Loss: 0.0551
# Epoch [3/10], Batch [300/508], Loss: 0.0612
# Epoch [3/10], Batch [400/508], Loss: 0.0626
# Epoch [3/10], Batch [500/508], Loss: 0.0545
# Epoch [3/10], Train Loss: 0.0608, Validation Loss: 0.0585
# Epoch [4/10], Batch [100/508], Loss: 0.0613
# Epoch [4/10], Batch [200/508], Loss: 0.0501
# Epoch [4/10], Batch [300/508], Loss: 0.0523
# Epoch [4/10], Batch [400/508], Loss: 0.0528
# Epoch [4/10], Batch [500/508], Loss: 0.0476
# Epoch [4/10], Train Loss: 0.0546, Validation Loss: 0.0535
# Epoch [5/10], Batch [100/508], Loss: 0.0495
# Epoch [5/10], Batch [200/508], Loss: 0.0542
# Epoch [5/10], Batch [300/508], Loss: 0.0445
# Epoch [5/10], Batch [400/508], Loss: 0.0499
# Epoch [5/10], Batch [500/508], Loss: 0.0476
# Epoch [5/10], Train Loss: 0.0516, Validation Loss: 0.0511
# Epoch [6/10], Batch [100/508], Loss: 0.0504
# Epoch [6/10], Batch [200/508], Loss: 0.0446
# Epoch [6/10], Batch [300/508], Loss: 0.0518
# Epoch [6/10], Batch [400/508], Loss: 0.0497
# Epoch [6/10], Batch [500/508], Loss: 0.0483
# Epoch [6/10], Train Loss: 0.0498, Validation Loss: 0.0493
# Epoch [7/10], Batch [100/508], Loss: 0.0561
# Epoch [7/10], Batch [200/508], Loss: 0.0547
# Epoch [7/10], Batch [300/508], Loss: 0.0569
# Epoch [7/10], Batch [400/508], Loss: 0.0491
# Epoch [7/10], Batch [500/508], Loss: 0.0495
# Epoch [7/10], Train Loss: 0.0489, Validation Loss: 0.0485
# Epoch [8/10], Batch [100/508], Loss: 0.0441
# Epoch [8/10], Batch [200/508], Loss: 0.0665
# Epoch [8/10], Batch [300/508], Loss: 0.0498
# Epoch [8/10], Batch [400/508], Loss: 0.0524
# Epoch [8/10], Batch [500/508], Loss: 0.0459
# Epoch [8/10], Train Loss: 0.0481, Validation Loss: 0.0478
# Epoch [9/10], Batch [100/508], Loss: 0.0444
# Epoch [9/10], Batch [200/508], Loss: 0.0465
# Epoch [9/10], Batch [300/508], Loss: 0.0542
# Epoch [9/10], Batch [400/508], Loss: 0.0492
# Epoch [9/10], Batch [500/508], Loss: 0.0412
# Epoch [9/10], Train Loss: 0.0476, Validation Loss: 0.0474
# Epoch [10/10], Batch [100/508], Loss: 0.0449
# Epoch [10/10], Batch [200/508], Loss: 0.0440
# Epoch [10/10], Batch [300/508], Loss: 0.0454
# Epoch [10/10], Batch [400/508], Loss: 0.0465
# Epoch [10/10], Batch [500/508], Loss: 0.0450
# Epoch [10/10], Train Loss: 0.0472, Validation Loss: 0.0469
# Fold 1 Validation Loss: 0.0469
# Processing fold 2/3 with hyperparameters: {'learning_rate': 0.0001, 'kl_weight': 1.0, 'latent_dim': 64, 'batch_size': 128}
# Epoch [1/10], Batch [100/508], Loss: 0.3320
# Epoch [1/10], Batch [200/508], Loss: 0.1607
# Epoch [1/10], Batch [300/508], Loss: 0.1343
# Epoch [1/10], Batch [400/508], Loss: 0.1145
# Epoch [1/10], Batch [500/508], Loss: 0.1010
# Epoch [1/10], Train Loss: 0.4870, Validation Loss: 0.0975
# Epoch [2/10], Batch [100/508], Loss: 0.0838
# Epoch [2/10], Batch [200/508], Loss: 0.0751
# Epoch [2/10], Batch [300/508], Loss: 0.0789
# Epoch [2/10], Batch [400/508], Loss: 0.0766
# Epoch [2/10], Batch [500/508], Loss: 0.0654
# Epoch [2/10], Train Loss: 0.0772, Validation Loss: 0.0682
# Epoch [3/10], Batch [100/508], Loss: 0.0671
# Epoch [3/10], Batch [200/508], Loss: 0.0603
# Epoch [3/10], Batch [300/508], Loss: 0.0561
# Epoch [3/10], Batch [400/508], Loss: 0.0545
# Epoch [3/10], Batch [500/508], Loss: 0.0544
# Epoch [3/10], Train Loss: 0.0596, Validation Loss: 0.0573
# Epoch [4/10], Batch [100/508], Loss: 0.0533
# Epoch [4/10], Batch [200/508], Loss: 0.0471
# Epoch [4/10], Batch [300/508], Loss: 0.0520
# Epoch [4/10], Batch [400/508], Loss: 0.0585
# Epoch [4/10], Batch [500/508], Loss: 0.0511
# Epoch [4/10], Train Loss: 0.0533, Validation Loss: 0.0526
# Epoch [5/10], Batch [100/508], Loss: 0.0515
# Epoch [5/10], Batch [200/508], Loss: 0.0601
# Epoch [5/10], Batch [300/508], Loss: 0.0468
# Epoch [5/10], Batch [400/508], Loss: 0.0542
# Epoch [5/10], Batch [500/508], Loss: 0.0546
# Epoch [5/10], Train Loss: 0.0508, Validation Loss: 0.0507
# Epoch [6/10], Batch [100/508], Loss: 0.0498
# Epoch [6/10], Batch [200/508], Loss: 0.0605
# Epoch [6/10], Batch [300/508], Loss: 0.0489
# Epoch [6/10], Batch [400/508], Loss: 0.0518
# Epoch [6/10], Batch [500/508], Loss: 0.0465
# Epoch [6/10], Train Loss: 0.0492, Validation Loss: 0.0492
# Epoch [7/10], Batch [100/508], Loss: 0.0464
# Epoch [7/10], Batch [200/508], Loss: 0.0476
# Epoch [7/10], Batch [300/508], Loss: 0.0470
# Epoch [7/10], Batch [400/508], Loss: 0.0530
# Epoch [7/10], Batch [500/508], Loss: 0.0471
# Epoch [7/10], Train Loss: 0.0484, Validation Loss: 0.0486
# Epoch [8/10], Batch [100/508], Loss: 0.0460
# Epoch [8/10], Batch [200/508], Loss: 0.0497
# Epoch [8/10], Batch [300/508], Loss: 0.0447
# Epoch [8/10], Batch [400/508], Loss: 0.0505
# Epoch [8/10], Batch [500/508], Loss: 0.0408
# Epoch [8/10], Train Loss: 0.0479, Validation Loss: 0.0483
# Epoch [9/10], Batch [100/508], Loss: 0.0506
# Epoch [9/10], Batch [200/508], Loss: 0.0511
# Epoch [9/10], Batch [300/508], Loss: 0.0416
# Epoch [9/10], Batch [400/508], Loss: 0.0535
# Epoch [9/10], Batch [500/508], Loss: 0.0529
# Epoch [9/10], Train Loss: 0.0475, Validation Loss: 0.0475
# Epoch [10/10], Batch [100/508], Loss: 0.0483
# Epoch [10/10], Batch [200/508], Loss: 0.0423
# Epoch [10/10], Batch [300/508], Loss: 0.0467
# Epoch [10/10], Batch [400/508], Loss: 0.0498
# Epoch [10/10], Batch [500/508], Loss: 0.0524
# Epoch [10/10], Train Loss: 0.0470, Validation Loss: 0.0474
# Fold 2 Validation Loss: 0.0474
# Processing fold 3/3 with hyperparameters: {'learning_rate': 0.0001, 'kl_weight': 1.0, 'latent_dim': 64, 'batch_size': 128}
# Epoch [1/10], Batch [100/508], Loss: 0.3464
# Epoch [1/10], Batch [200/508], Loss: 0.1919
# Epoch [1/10], Batch [300/508], Loss: 0.1292
# Epoch [1/10], Batch [400/508], Loss: 0.1239
# Epoch [1/10], Batch [500/508], Loss: 0.0963
# Epoch [1/10], Train Loss: 0.5176, Validation Loss: 0.0994
# Epoch [2/10], Batch [100/508], Loss: 0.0873
# Epoch [2/10], Batch [200/508], Loss: 0.0964
# Epoch [2/10], Batch [300/508], Loss: 0.0740
# Epoch [2/10], Batch [400/508], Loss: 0.0690
# Epoch [2/10], Batch [500/508], Loss: 0.0700
# Epoch [2/10], Train Loss: 0.0783, Validation Loss: 0.0705
# Epoch [3/10], Batch [100/508], Loss: 0.0646
# Epoch [3/10], Batch [200/508], Loss: 0.0629
# Epoch [3/10], Batch [300/508], Loss: 0.0577
# Epoch [3/10], Batch [400/508], Loss: 0.0609
# Epoch [3/10], Batch [500/508], Loss: 0.0559
# Epoch [3/10], Train Loss: 0.0612, Validation Loss: 0.0595
# Epoch [4/10], Batch [100/508], Loss: 0.0622
# Epoch [4/10], Batch [200/508], Loss: 0.0508
# Epoch [4/10], Batch [300/508], Loss: 0.0531
# Epoch [4/10], Batch [400/508], Loss: 0.0503
# Epoch [4/10], Batch [500/508], Loss: 0.0516
# Epoch [4/10], Train Loss: 0.0548, Validation Loss: 0.0543
# Epoch [5/10], Batch [100/508], Loss: 0.0507
# Epoch [5/10], Batch [200/508], Loss: 0.0501
# Epoch [5/10], Batch [300/508], Loss: 0.0452
# Epoch [5/10], Batch [400/508], Loss: 0.0503
# Epoch [5/10], Batch [500/508], Loss: 0.0628
# Epoch [5/10], Train Loss: 0.0515, Validation Loss: 0.0516
# Epoch [6/10], Batch [100/508], Loss: 0.0520
# Epoch [6/10], Batch [200/508], Loss: 0.0558
# Epoch [6/10], Batch [300/508], Loss: 0.0558
# Epoch [6/10], Batch [400/508], Loss: 0.0476
# Epoch [6/10], Batch [500/508], Loss: 0.0483
# Epoch [6/10], Train Loss: 0.0498, Validation Loss: 0.0498
# Epoch [7/10], Batch [100/508], Loss: 0.0497
# Epoch [7/10], Batch [200/508], Loss: 0.0464
# Epoch [7/10], Batch [300/508], Loss: 0.0448
# Epoch [7/10], Batch [400/508], Loss: 0.0505
# Epoch [7/10], Batch [500/508], Loss: 0.0427
# Epoch [7/10], Train Loss: 0.0486, Validation Loss: 0.0487
# Epoch [8/10], Batch [100/508], Loss: 0.0449
# Epoch [8/10], Batch [200/508], Loss: 0.0459
# Epoch [8/10], Batch [300/508], Loss: 0.0528
# Epoch [8/10], Batch [400/508], Loss: 0.0528
# Epoch [8/10], Batch [500/508], Loss: 0.0504
# Epoch [8/10], Train Loss: 0.0480, Validation Loss: 0.0480
# Epoch [9/10], Batch [100/508], Loss: 0.0521
# Epoch [9/10], Batch [200/508], Loss: 0.0501
# Epoch [9/10], Batch [300/508], Loss: 0.0451
# Epoch [9/10], Batch [400/508], Loss: 0.0504
# Epoch [9/10], Batch [500/508], Loss: 0.0491
# Epoch [9/10], Train Loss: 0.0475, Validation Loss: 0.0475
# Epoch [10/10], Batch [100/508], Loss: 0.0518
# Epoch [10/10], Batch [200/508], Loss: 0.0448
# Epoch [10/10], Batch [300/508], Loss: 0.0478
# Epoch [10/10], Batch [400/508], Loss: 0.0515
# Epoch [10/10], Batch [500/508], Loss: 0.0474
# Epoch [10/10], Train Loss: 0.0471, Validation Loss: 0.0470
# Fold 3 Validation Loss: 0.0470
# Current best validation loss: 0.0460 with hyperparameters: {'learning_rate': 0.001, 'kl_weight': 1.0, 'latent_dim': 64, 'batch_size': 128}
# Best hyperparameters: {'learning_rate': 0.001, 'kl_weight': 1.0, 'latent_dim': 64, 'batch_size': 128}
# Best validation loss: 0.045977282369621786

# %%
# Train and evaluate the final model with the best hyperparameters
best_learning_rate = best_params['learning_rate']
#best_kl_weight = best_params['kl_weight']
best_kl_weight=0.1
#best_latent_dim = best_params['latent_dim']
best_latent_dim=256
hidden_dims=[2048, 1024, 512]

best_batch_size = best_params['batch_size']


# Update dataloaders with the best batch size
train_loader = DataLoader(train_dataset, batch_size=best_batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=best_batch_size)
test_loader = DataLoader(test_dataset, batch_size=best_batch_size)

# Define the final model with the best hyperparameters
model = VAE(input_dim, hidden_dims, best_latent_dim).to(device)
optimizer = optim.Adam(model.parameters(), lr=best_learning_rate, weight_decay=1e-5)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Train the final model
train_losses, val_losses = train_model(model, train_loader, val_loader, vae_loss_function, optimizer, scheduler, num_epochs, device)
# Out:
# Epoch [1/15], Batch [100/762], Loss: 0.0509
# Epoch [1/15], Batch [200/762], Loss: 0.0596
# Epoch [1/15], Batch [300/762], Loss: 0.0549
# Epoch [1/15], Batch [400/762], Loss: 0.0500
# Epoch [1/15], Batch [500/762], Loss: 0.0529
# Epoch [1/15], Batch [600/762], Loss: 0.0529
# Epoch [1/15], Batch [700/762], Loss: 0.0574
# Epoch [1/15], Train Loss: 0.1792, Validation Loss: 0.0472
# Epoch [2/15], Batch [100/762], Loss: 0.0468
# Epoch [2/15], Batch [200/762], Loss: 0.0503
# Epoch [2/15], Batch [300/762], Loss: 0.0497
# Epoch [2/15], Batch [400/762], Loss: 0.0414
# Epoch [2/15], Batch [500/762], Loss: 0.0476
# Epoch [2/15], Batch [600/762], Loss: 0.0439
# Epoch [2/15], Batch [700/762], Loss: 0.0537
# Epoch [2/15], Train Loss: 0.0470, Validation Loss: 0.0462
# Epoch [3/15], Batch [100/762], Loss: 0.0419
# Epoch [3/15], Batch [200/762], Loss: 0.0522
# Epoch [3/15], Batch [300/762], Loss: 0.0541
# Epoch [3/15], Batch [400/762], Loss: 0.0457
# Epoch [3/15], Batch [500/762], Loss: 0.0424
# Epoch [3/15], Batch [600/762], Loss: 0.0421
# Epoch [3/15], Batch [700/762], Loss: 0.0404
# Epoch [3/15], Train Loss: 0.0465, Validation Loss: 0.0461
# Epoch [4/15], Batch [100/762], Loss: 0.0510
# Epoch [4/15], Batch [200/762], Loss: 0.0507
# Epoch [4/15], Batch [300/762], Loss: 0.0399
# Epoch [4/15], Batch [400/762], Loss: 0.0398
# Epoch [4/15], Batch [500/762], Loss: 0.0572
# Epoch [4/15], Batch [600/762], Loss: 0.0427
# Epoch [4/15], Batch [700/762], Loss: 0.0479
# Epoch [4/15], Train Loss: 0.0464, Validation Loss: 0.0464
# Epoch [5/15], Batch [100/762], Loss: 0.0489
# Epoch [5/15], Batch [200/762], Loss: 0.0442
# Epoch [5/15], Batch [300/762], Loss: 0.0490
# Epoch [5/15], Batch [400/762], Loss: 0.0511
# Epoch [5/15], Batch [500/762], Loss: 0.0671
# Epoch [5/15], Batch [600/762], Loss: 0.0456
# Epoch [5/15], Batch [700/762], Loss: 0.0444
# Epoch [5/15], Train Loss: 0.0462, Validation Loss: 0.0463
# Epoch [6/15], Batch [100/762], Loss: 0.0571
# Epoch [6/15], Batch [200/762], Loss: 0.0454
# Epoch [6/15], Batch [300/762], Loss: 0.0454
# Epoch [6/15], Batch [400/762], Loss: 0.0422
# Epoch [6/15], Batch [500/762], Loss: 0.0469
# Epoch [6/15], Batch [600/762], Loss: 0.0464
# Epoch [6/15], Batch [700/762], Loss: 0.0456
# Epoch [6/15], Train Loss: 0.0462, Validation Loss: 0.0459
# Epoch [7/15], Batch [100/762], Loss: 0.0394
# Epoch [7/15], Batch [200/762], Loss: 0.0461
# Epoch [7/15], Batch [300/762], Loss: 0.0480
# Epoch [7/15], Batch [400/762], Loss: 0.0463
# Epoch [7/15], Batch [500/762], Loss: 0.0510
# Epoch [7/15], Batch [600/762], Loss: 0.0429
# Epoch [7/15], Batch [700/762], Loss: 0.0408
# Epoch [7/15], Train Loss: 0.0461, Validation Loss: 0.0463
# Epoch [8/15], Batch [100/762], Loss: 0.0500
# Epoch [8/15], Batch [200/762], Loss: 0.0442
# Epoch [8/15], Batch [300/762], Loss: 0.0524
# Epoch [8/15], Batch [400/762], Loss: 0.0465
# Epoch [8/15], Batch [500/762], Loss: 0.0428
# Epoch [8/15], Batch [600/762], Loss: 0.0464
# Epoch [8/15], Batch [700/762], Loss: 0.0430
# Epoch [8/15], Train Loss: 0.0460, Validation Loss: 0.0456
# Epoch [9/15], Batch [100/762], Loss: 0.0440
# Epoch [9/15], Batch [200/762], Loss: 0.0431
# Epoch [9/15], Batch [300/762], Loss: 0.0417
# Epoch [9/15], Batch [400/762], Loss: 0.0467
# Epoch [9/15], Batch [500/762], Loss: 0.0510
# Epoch [9/15], Batch [600/762], Loss: 0.0412
# Epoch [9/15], Batch [700/762], Loss: 0.0393
# Epoch [9/15], Train Loss: 0.0459, Validation Loss: 0.0458
# Epoch [10/15], Batch [100/762], Loss: 0.0530
# Epoch [10/15], Batch [200/762], Loss: 0.0461
# Epoch [10/15], Batch [300/762], Loss: 0.0533
# Epoch [10/15], Batch [400/762], Loss: 0.0439
# Epoch [10/15], Batch [500/762], Loss: 0.0397
# Epoch [10/15], Batch [600/762], Loss: 0.0456
# Epoch [10/15], Batch [700/762], Loss: 0.0420
# Epoch [10/15], Train Loss: 0.0459, Validation Loss: 0.0465
# Epoch [11/15], Batch [100/762], Loss: 0.0409
# Epoch [11/15], Batch [200/762], Loss: 0.0438
# Epoch [11/15], Batch [300/762], Loss: 0.0354
# Epoch [11/15], Batch [400/762], Loss: 0.0504
# Epoch [11/15], Batch [500/762], Loss: 0.0408
# Epoch [11/15], Batch [600/762], Loss: 0.0462
# Epoch [11/15], Batch [700/762], Loss: 0.0394
# Epoch [11/15], Train Loss: 0.0451, Validation Loss: 0.0450
# Epoch [12/15], Batch [100/762], Loss: 0.0442
# Epoch [12/15], Batch [200/762], Loss: 0.0538
# Epoch [12/15], Batch [300/762], Loss: 0.0387
# Epoch [12/15], Batch [400/762], Loss: 0.0426
# Epoch [12/15], Batch [500/762], Loss: 0.0511
# Epoch [12/15], Batch [600/762], Loss: 0.0422
# Epoch [12/15], Batch [700/762], Loss: 0.0544
# Epoch [12/15], Train Loss: 0.0451, Validation Loss: 0.0450
# Epoch [13/15], Batch [100/762], Loss: 0.0416
# Epoch [13/15], Batch [200/762], Loss: 0.0532
# Epoch [13/15], Batch [300/762], Loss: 0.0564
# Epoch [13/15], Batch [400/762], Loss: 0.0429
# Epoch [13/15], Batch [500/762], Loss: 0.0461
# Epoch [13/15], Batch [600/762], Loss: 0.0452
# Epoch [13/15], Batch [700/762], Loss: 0.0477
# Epoch [13/15], Train Loss: 0.0451, Validation Loss: 0.0450
# Epoch [14/15], Batch [100/762], Loss: 0.0418
# Epoch [14/15], Batch [200/762], Loss: 0.0547
# Epoch [14/15], Batch [300/762], Loss: 0.0422
# Epoch [14/15], Batch [400/762], Loss: 0.0446
# Epoch [14/15], Batch [500/762], Loss: 0.0480
# Epoch [14/15], Batch [600/762], Loss: 0.0422
# Epoch [14/15], Batch [700/762], Loss: 0.0440
# Epoch [14/15], Train Loss: 0.0451, Validation Loss: 0.0450
# Epoch [15/15], Batch [100/762], Loss: 0.0412
# Epoch [15/15], Batch [200/762], Loss: 0.0421
# Epoch [15/15], Batch [300/762], Loss: 0.0412
# Epoch [15/15], Batch [400/762], Loss: 0.0429
# Epoch [15/15], Batch [500/762], Loss: 0.0460
# Epoch [15/15], Batch [600/762], Loss: 0.0460
# Epoch [15/15], Batch [700/762], Loss: 0.0483
# Epoch [15/15], Train Loss: 0.0451, Validation Loss: 0.0450

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs + 1), train_losses, label='Train Loss')
plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
compare_user_ratings_normalized(3, model, device)
# Out:
#                                              title  OriginalRating
# 0                              Pulp Fiction (1994)        1.000000  \
# 1                                       Ran (1985)        1.000000
# 2                                   Gattaca (1997)        1.000000
# 3                              Moulin Rouge (2001)        0.555556
# 4    Lord of the Rings: The Two Towers, The (2002)        0.777778
# ..                                             ...             ...
# 642                       Blade Runner 2049 (2017)        0.888889
# 643                Star Wars: The Last Jedi (2017)        0.666667
# 644                                  Bright (2017)        0.555556
# 645                           Incredibles 2 (2018)        0.666667
# 646                              Deadpool 2 (2018)        0.888889
#
#      PredictedRating
# 0           0.819916
# 1           0.811257
# 2           0.730171
# 3           0.657213
# 4           0.792853
# ..               ...
# 642         0.761135
# 643         0.654336
# 644         0.538791
# 645         0.720846
# 646         0.732970
#
# [647 rows x 3 columns]

# %%
completed_matrix = generate_completed_matrix(model, user_item_matrix, device)

# Flatten the completed matrix to get all predicted ratings
predicted_ratings = completed_matrix.flatten()

# Plot the distribution of the predicted ratings
plt.figure(figsize=(10, 6))
plt.hist(predicted_ratings, bins=30, edgecolor='black')
plt.title('Distribution of Predicted Ratings - VAE')
plt.xlabel('Predicted Ratings (Normalized)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 completed_matrix = generate_completed_matrix(model, user_item_matrix, device)
#       3 # Flatten the completed matrix to get all predicted ratings
#       4 predicted_ratings = completed_matrix.flatten()
#
# Cell In[26], line 9, in generate_completed_matrix(model, user_item_matrix, device)
#       6 model.eval()
#       7 with torch.no_grad():
#       8     # Convert the entire user-item matrix to a tensor and move it to the device
# ----> 9     user_item_tensor = torch.from_numpy(user_item_matrix.toarray()).float().to(device)
#      11     # Pass the tensor through the model to get predicted ratings
#      12     outputs = model(user_item_tensor)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\scipy\sparse\_compressed.py:1056, in _cs_matrix.toarray(self, order, out)
#    1054 if out is None and order is None:
#    1055     order = self._swap('cf')[0]
# -> 1056 out = self._process_toarray_args(order, out)
#    1057 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1058     raise ValueError('Output array must be C or F contiguous')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\scipy\sparse\_base.py:1287, in _spbase._process_toarray_args(self, order, out)
#    1285     return out
#    1286 else:
# -> 1287     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 6.06 GiB for an array with shape (162539, 5000) and data type float64
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Evaluate the final model on the test set
train_rmse, train_mae, train_loss = evaluate_model(model, train_loader, vae_loss_function, device)
val_rmse, val_mae, val_loss = evaluate_model(model, val_loader, vae_loss_function, device)
test_rmse, test_mae, test_loss = evaluate_model(model, test_loader, vae_loss_function, device)

print(f'Train RMSE: {train_rmse:.4f}, Train MAE: {train_mae:.4f}, Train Loss: {train_loss:.4f}')
print(f'Validation RMSE: {val_rmse:.4f}, Validation MAE: {val_mae:.4f}, Validation Loss: {val_loss:.4f}')
print(f'Test RMSE: {test_rmse:.4f}, Test MAE: {test_mae:.4f}, Test Loss: {test_loss:.4f}')
